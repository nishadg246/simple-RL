# %%
run "gp_rtdp_bq.py"
# Out:
# ITERATION 0
# (30.0, 30.0)
# 4.6330558325667655
# (29.88164956032741, 29.360911065431928)
# 4.696522350821105
# (29.511686650309382, 28.070717439372846)
# 4.759988869075444
# (29.2464519447299, 26.978229318111733)
# 4.823455387329783
# (29.334688572355496, 25.61155978271446)
# 4.3791897595494085
# (28.760695790391537, 24.059109641028368)
# 3.998390650023373
# (28.542321296087437, 23.32189718481615)
# 3.744524577006016
# (28.119040581982233, 22.451127725430474)
# 3.42719198573432
# (27.159781943598258, 22.367626046219193)
# 3.998390650023373
# (26.514893542553935, 21.829923479195653)
# 3.8714576135146945
# (26.2060412225652, 21.050368509804464)
# 3.8714576135146945
# (25.052892765209517, 20.802903194886778)
# 3.744524577006016
# (24.502686671687957, 19.90445389551573)
# 3.42719198573432
# (23.91101990932171, 19.60547905072537)
# 4.1253236865320515
# (23.164070030960737, 19.29214393835774)
# 3.6175915404973376
# (21.957190480302906, 19.383776811820518)
# 3.934924131769034
# (20.877574241448656, 18.51166622196843)
# 3.998390650023373
# (20.40384030331526, 17.337449083620108)
# 4.188790204786391
# (19.865568666344288, 16.86822793235016)
# 4.442656277803748
# (19.498701164159954, 15.768289993476653)
# 3.42719198573432
# (19.498701164159954, 15.768289993476653)
# 3.42719198573432
# (18.007452103297258, 15.767107132010738)
# 3.8714576135146945
# (18.007452103297258, 15.767107132010738)
# 4.1253236865320515
# (18.007452103297258, 15.767107132010738)
# 3.8079910952603555
# (17.275393710688874, 15.590750603141602)
# 5.331187533364497
# (17.275393710688874, 15.590750603141602)
# 5.711986642890533
# (17.275393710688874, 15.590750603141602)
# 5.838919679399211
# (17.596043218541354, 15.04312827724832)
# 3.5541250222429985
# (17.596043218541354, 15.04312827724832)
# 3.3002589492256416
# (17.596043218541354, 15.04312827724832)
# 3.934924131769034
# (17.596043218541354, 15.04312827724832)
# 3.8714576135146945
# (17.596043218541354, 15.04312827724832)
# 3.934924131769034
# (17.596043218541354, 15.04312827724832)
# 3.934924131769034
# (17.596043218541354, 15.04312827724832)
# 3.934924131769034
# (17.596043218541354, 15.04312827724832)
# 3.8079910952603555
# (17.596043218541354, 15.04312827724832)
# 3.934924131769034
# (17.596043218541354, 15.04312827724832)
# 3.8714576135146945
# (17.596043218541354, 15.04312827724832)
# 3.5541250222429985
# (17.596043218541354, 15.04312827724832)
# 3.42719198573432
# (17.596043218541354, 15.04312827724832)
# 3.5541250222429985
# (17.596043218541354, 15.04312827724832)
# 3.934924131769034
# (17.596043218541354, 15.04312827724832)
# 3.236792430971302
# (17.596043218541354, 15.04312827724832)
# 3.3637254674799806
# (17.596043218541354, 15.04312827724832)
# 3.3637254674799806
# (17.048852715680617, 15.199499852757958)
# 5.648520124636194
# (17.048852715680617, 15.199499852757958)
# 6.092785752416569
# (17.80369434506271, 15.626096622122056)
# 3.5541250222429985
# (17.80369434506271, 15.626096622122056)
# 3.934924131769034
# (17.064192889680196, 15.399913866350344)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/nishad/Documents/simple-RL/gp_rtdp_bq.py in <module>()
#     307
#     308 p = PWorld()
# --> 309 valueFunc = p.RTDP()
#     310 # valueFunc = p.valueiteration()
#     311
#
# /home/nishad/Documents/simple-RL/gp_rtdp_bq.py in RTDP(self)
#     176         for i in range(self.ITERS):
#     177             print "ITERATION %d" % (i)
# --> 178             D_temp = TrialRecurseWrapper(self.startX,self.startY,i,VGP)
#     179             self.Dicts.append(D_temp)
#     180             VGP, _,_ = self.GPFromDict(self.mergeLastN(self.Dicts,1))
#
# /home/nishad/Documents/simple-RL/gp_rtdp_bq.py in TrialRecurseWrapper(ax, ay, iteration, VGP)
#     171                 D_temp[(x,y)] = Q[maxa]
#     172
# --> 173             TrialRecurse(ax,ay,VGP)
#     174             return D_temp
#     175
#
# /home/nishad/Documents/simple-RL/gp_rtdp_bq.py in TrialRecurse(x, y, VGP)
#     164                 print maxa
#     165                 (sx,sy) = self.computeResult(x,y,maxa)
# --> 166                 TrialRecurse(sx,sy,VGP)
#     167                 VGP, _,_ = self.GPFromDict(self.mergeLastN(self.Dicts+[D_temp],1))
#     168                 Q = self.Qestimate(x,y,VGP)
#
# /home/nishad/Documents/simple-RL/gp_rtdp_bq.py in TrialRecurse(x, y, VGP)
#     164                 print maxa
#     165                 (sx,sy) = self.computeResult(x,y,maxa)
# --> 166                 TrialRecurse(sx,sy,VGP)
#     167                 VGP, _,_ = self.GPFromDict(self.mergeLastN(self.Dicts+[D_temp],1))
#     168                 Q = self.Qestimate(x,y,VGP)
#
# /home/nishad/Documents/simple-RL/gp_rtdp_bq.py in TrialRecurse(x, y, VGP)
#     164                 print maxa
#     165                 (sx,sy) = self.computeResult(x,y,maxa)
# --> 166                 TrialRecurse(sx,sy,VGP)
#     167                 VGP, _,_ = self.GPFromDict(self.mergeLastN(self.Dicts+[D_temp],1))
#     168                 Q = self.Qestimate(x,y,VGP)
#
# /home/nishad/Documents/simple-RL/gp_rtdp_bq.py in TrialRecurse(x, y, VGP)
#     164                 print maxa
#     165                 (sx,sy) = self.computeResult(x,y,maxa)
# --> 166                 TrialRecurse(sx,sy,VGP)
#     167                 VGP, _,_ = self.GPFromDict(self.mergeLastN(self.Dicts+[D_temp],1))
#     168                 Q = self.Qestimate(x,y,VGP)
#
# /home/nishad/Documents/simple-RL/gp_rtdp_bq.py in TrialRecurse(x, y, VGP)
#     164                 print maxa
#     165                 (sx,sy) = self.computeResult(x,y,maxa)
# --> 166                 TrialRecurse(sx,sy,VGP)
#     167                 VGP, _,_ = self.GPFromDict(self.mergeLastN(self.Dicts+[D_temp],1))
#     168                 Q = self.Qestimate(x,y,VGP)
#
# /home/nishad/Documents/simple-RL/gp_rtdp_bq.py in TrialRecurse(x, y, VGP)
#     164                 print maxa
#     165                 (sx,sy) = self.computeResult(x,y,maxa)
# --> 166                 TrialRecurse(sx,sy,VGP)
#     167                 VGP, _,_ = self.GPFromDict(self.mergeLastN(self.Dicts+[D_temp],1))
#     168                 Q = self.Qestimate(x,y,VGP)
#
# /home/nishad/Documents/simple-RL/gp_rtdp_bq.py in TrialRecurse(x, y, VGP)
#     164                 print maxa
#     165                 (sx,sy) = self.computeResult(x,y,maxa)
# --> 166                 TrialRecurse(sx,sy,VGP)
#     167                 VGP, _,_ = self.GPFromDict(self.mergeLastN(self.Dicts+[D_temp],1))
#     168                 Q = self.Qestimate(x,y,VGP)
#
# /home/nishad/Documents/simple-RL/gp_rtdp_bq.py in TrialRecurse(x, y, VGP)
#     164                 print maxa
#     165                 (sx,sy) = self.computeResult(x,y,maxa)
# --> 166                 TrialRecurse(sx,sy,VGP)
#     167                 VGP, _,_ = self.GPFromDict(self.mergeLastN(self.Dicts+[D_temp],1))
#     168                 Q = self.Qestimate(x,y,VGP)
#
# /home/nishad/Documents/simple-RL/gp_rtdp_bq.py in TrialRecurse(x, y, VGP)
#     164                 print maxa
#     165                 (sx,sy) = self.computeResult(x,y,maxa)
# --> 166                 TrialRecurse(sx,sy,VGP)
#     167                 VGP, _,_ = self.GPFromDict(self.mergeLastN(self.Dicts+[D_temp],1))
#     168                 Q = self.Qestimate(x,y,VGP)
#
# /home/nishad/Documents/simple-RL/gp_rtdp_bq.py in TrialRecurse(x, y, VGP)
#     164                 print maxa
#     165                 (sx,sy) = self.computeResult(x,y,maxa)
# --> 166                 TrialRecurse(sx,sy,VGP)
#     167                 VGP, _,_ = self.GPFromDict(self.mergeLastN(self.Dicts+[D_temp],1))
#     168                 Q = self.Qestimate(x,y,VGP)
#
# /home/nishad/Documents/simple-RL/gp_rtdp_bq.py in TrialRecurse(x, y, VGP)
#     164                 print maxa
#     165                 (sx,sy) = self.computeResult(x,y,maxa)
# --> 166                 TrialRecurse(sx,sy,VGP)
#     167                 VGP, _,_ = self.GPFromDict(self.mergeLastN(self.Dicts+[D_temp],1))
#     168                 Q = self.Qestimate(x,y,VGP)
#
# /home/nishad/Documents/simple-RL/gp_rtdp_bq.py in TrialRecurse(x, y, VGP)
#     164                 print maxa
#     165                 (sx,sy) = self.computeResult(x,y,maxa)
# --> 166                 TrialRecurse(sx,sy,VGP)
#     167                 VGP, _,_ = self.GPFromDict(self.mergeLastN(self.Dicts+[D_temp],1))
#     168                 Q = self.Qestimate(x,y,VGP)
#
# /home/nishad/Documents/simple-RL/gp_rtdp_bq.py in TrialRecurse(x, y, VGP)
#     164                 print maxa
#     165                 (sx,sy) = self.computeResult(x,y,maxa)
# --> 166                 TrialRecurse(sx,sy,VGP)
#     167                 VGP, _,_ = self.GPFromDict(self.mergeLastN(self.Dicts+[D_temp],1))
#     168                 Q = self.Qestimate(x,y,VGP)
#
# /home/nishad/Documents/simple-RL/gp_rtdp_bq.py in TrialRecurse(x, y, VGP)
#     164                 print maxa
#     165                 (sx,sy) = self.computeResult(x,y,maxa)
# --> 166                 TrialRecurse(sx,sy,VGP)
#     167                 VGP, _,_ = self.GPFromDict(self.mergeLastN(self.Dicts+[D_temp],1))
#     168                 Q = self.Qestimate(x,y,VGP)
#
# /home/nishad/Documents/simple-RL/gp_rtdp_bq.py in TrialRecurse(x, y, VGP)
#     164                 print maxa
#     165                 (sx,sy) = self.computeResult(x,y,maxa)
# --> 166                 TrialRecurse(sx,sy,VGP)
#     167                 VGP, _,_ = self.GPFromDict(self.mergeLastN(self.Dicts+[D_temp],1))
#     168                 Q = self.Qestimate(x,y,VGP)
#
# /home/nishad/Documents/simple-RL/gp_rtdp_bq.py in TrialRecurse(x, y, VGP)
#     164                 print maxa
#     165                 (sx,sy) = self.computeResult(x,y,maxa)
# --> 166                 TrialRecurse(sx,sy,VGP)
#     167                 VGP, _,_ = self.GPFromDict(self.mergeLastN(self.Dicts+[D_temp],1))
#     168                 Q = self.Qestimate(x,y,VGP)
#
# /home/nishad/Documents/simple-RL/gp_rtdp_bq.py in TrialRecurse(x, y, VGP)
#     164                 print maxa
#     165                 (sx,sy) = self.computeResult(x,y,maxa)
# --> 166                 TrialRecurse(sx,sy,VGP)
#     167                 VGP, _,_ = self.GPFromDict(self.mergeLastN(self.Dicts+[D_temp],1))
#     168                 Q = self.Qestimate(x,y,VGP)
#
# /home/nishad/Documents/simple-RL/gp_rtdp_bq.py in TrialRecurse(x, y, VGP)
#     164                 print maxa
#     165                 (sx,sy) = self.computeResult(x,y,maxa)
# --> 166                 TrialRecurse(sx,sy,VGP)
#     167                 VGP, _,_ = self.GPFromDict(self.mergeLastN(self.Dicts+[D_temp],1))
#     168                 Q = self.Qestimate(x,y,VGP)
#
# /home/nishad/Documents/simple-RL/gp_rtdp_bq.py in TrialRecurse(x, y, VGP)
#     164                 print maxa
#     165                 (sx,sy) = self.computeResult(x,y,maxa)
# --> 166                 TrialRecurse(sx,sy,VGP)
#     167                 VGP, _,_ = self.GPFromDict(self.mergeLastN(self.Dicts+[D_temp],1))
#     168                 Q = self.Qestimate(x,y,VGP)
#
# /home/nishad/Documents/simple-RL/gp_rtdp_bq.py in TrialRecurse(x, y, VGP)
#     164                 print maxa
#     165                 (sx,sy) = self.computeResult(x,y,maxa)
# --> 166                 TrialRecurse(sx,sy,VGP)
#     167                 VGP, _,_ = self.GPFromDict(self.mergeLastN(self.Dicts+[D_temp],1))
#     168                 Q = self.Qestimate(x,y,VGP)
#
# /home/nishad/Documents/simple-RL/gp_rtdp_bq.py in TrialRecurse(x, y, VGP)
#     164                 print maxa
#     165                 (sx,sy) = self.computeResult(x,y,maxa)
# --> 166                 TrialRecurse(sx,sy,VGP)
#     167                 VGP, _,_ = self.GPFromDict(self.mergeLastN(self.Dicts+[D_temp],1))
#     168                 Q = self.Qestimate(x,y,VGP)
#
# /home/nishad/Documents/simple-RL/gp_rtdp_bq.py in TrialRecurse(x, y, VGP)
#     164                 print maxa
#     165                 (sx,sy) = self.computeResult(x,y,maxa)
# --> 166                 TrialRecurse(sx,sy,VGP)
#     167                 VGP, _,_ = self.GPFromDict(self.mergeLastN(self.Dicts+[D_temp],1))
#     168                 Q = self.Qestimate(x,y,VGP)
#
# /home/nishad/Documents/simple-RL/gp_rtdp_bq.py in TrialRecurse(x, y, VGP)
#     164                 print maxa
#     165                 (sx,sy) = self.computeResult(x,y,maxa)
# --> 166                 TrialRecurse(sx,sy,VGP)
#     167                 VGP, _,_ = self.GPFromDict(self.mergeLastN(self.Dicts+[D_temp],1))
#     168                 Q = self.Qestimate(x,y,VGP)
#
# /home/nishad/Documents/simple-RL/gp_rtdp_bq.py in TrialRecurse(x, y, VGP)
#     164                 print maxa
#     165                 (sx,sy) = self.computeResult(x,y,maxa)
# --> 166                 TrialRecurse(sx,sy,VGP)
#     167                 VGP, _,_ = self.GPFromDict(self.mergeLastN(self.Dicts+[D_temp],1))
#     168                 Q = self.Qestimate(x,y,VGP)
#
# /home/nishad/Documents/simple-RL/gp_rtdp_bq.py in TrialRecurse(x, y, VGP)
#     164                 print maxa
#     165                 (sx,sy) = self.computeResult(x,y,maxa)
# --> 166                 TrialRecurse(sx,sy,VGP)
#     167                 VGP, _,_ = self.GPFromDict(self.mergeLastN(self.Dicts+[D_temp],1))
#     168                 Q = self.Qestimate(x,y,VGP)
#
# /home/nishad/Documents/simple-RL/gp_rtdp_bq.py in TrialRecurse(x, y, VGP)
#     164                 print maxa
#     165                 (sx,sy) = self.computeResult(x,y,maxa)
# --> 166                 TrialRecurse(sx,sy,VGP)
#     167                 VGP, _,_ = self.GPFromDict(self.mergeLastN(self.Dicts+[D_temp],1))
#     168                 Q = self.Qestimate(x,y,VGP)
#
# /home/nishad/Documents/simple-RL/gp_rtdp_bq.py in TrialRecurse(x, y, VGP)
#     164                 print maxa
#     165                 (sx,sy) = self.computeResult(x,y,maxa)
# --> 166                 TrialRecurse(sx,sy,VGP)
#     167                 VGP, _,_ = self.GPFromDict(self.mergeLastN(self.Dicts+[D_temp],1))
#     168                 Q = self.Qestimate(x,y,VGP)
#
# /home/nishad/Documents/simple-RL/gp_rtdp_bq.py in TrialRecurse(x, y, VGP)
#     164                 print maxa
#     165                 (sx,sy) = self.computeResult(x,y,maxa)
# --> 166                 TrialRecurse(sx,sy,VGP)
#     167                 VGP, _,_ = self.GPFromDict(self.mergeLastN(self.Dicts+[D_temp],1))
#     168                 Q = self.Qestimate(x,y,VGP)
#
# /home/nishad/Documents/simple-RL/gp_rtdp_bq.py in TrialRecurse(x, y, VGP)
#     164                 print maxa
#     165                 (sx,sy) = self.computeResult(x,y,maxa)
# --> 166                 TrialRecurse(sx,sy,VGP)
#     167                 VGP, _,_ = self.GPFromDict(self.mergeLastN(self.Dicts+[D_temp],1))
#     168                 Q = self.Qestimate(x,y,VGP)
#
# /home/nishad/Documents/simple-RL/gp_rtdp_bq.py in TrialRecurse(x, y, VGP)
#     164                 print maxa
#     165                 (sx,sy) = self.computeResult(x,y,maxa)
# --> 166                 TrialRecurse(sx,sy,VGP)
#     167                 VGP, _,_ = self.GPFromDict(self.mergeLastN(self.Dicts+[D_temp],1))
#     168                 Q = self.Qestimate(x,y,VGP)
#
# /home/nishad/Documents/simple-RL/gp_rtdp_bq.py in TrialRecurse(x, y, VGP)
#     164                 print maxa
#     165                 (sx,sy) = self.computeResult(x,y,maxa)
# --> 166                 TrialRecurse(sx,sy,VGP)
#     167                 VGP, _,_ = self.GPFromDict(self.mergeLastN(self.Dicts+[D_temp],1))
#     168                 Q = self.Qestimate(x,y,VGP)
#
# /home/nishad/Documents/simple-RL/gp_rtdp_bq.py in TrialRecurse(x, y, VGP)
#     164                 print maxa
#     165                 (sx,sy) = self.computeResult(x,y,maxa)
# --> 166                 TrialRecurse(sx,sy,VGP)
#     167                 VGP, _,_ = self.GPFromDict(self.mergeLastN(self.Dicts+[D_temp],1))
#     168                 Q = self.Qestimate(x,y,VGP)
#
# /home/nishad/Documents/simple-RL/gp_rtdp_bq.py in TrialRecurse(x, y, VGP)
#     164                 print maxa
#     165                 (sx,sy) = self.computeResult(x,y,maxa)
# --> 166                 TrialRecurse(sx,sy,VGP)
#     167                 VGP, _,_ = self.GPFromDict(self.mergeLastN(self.Dicts+[D_temp],1))
#     168                 Q = self.Qestimate(x,y,VGP)
#
# /home/nishad/Documents/simple-RL/gp_rtdp_bq.py in TrialRecurse(x, y, VGP)
#     164                 print maxa
#     165                 (sx,sy) = self.computeResult(x,y,maxa)
# --> 166                 TrialRecurse(sx,sy,VGP)
#     167                 VGP, _,_ = self.GPFromDict(self.mergeLastN(self.Dicts+[D_temp],1))
#     168                 Q = self.Qestimate(x,y,VGP)
#
# /home/nishad/Documents/simple-RL/gp_rtdp_bq.py in TrialRecurse(x, y, VGP)
#     164                 print maxa
#     165                 (sx,sy) = self.computeResult(x,y,maxa)
# --> 166                 TrialRecurse(sx,sy,VGP)
#     167                 VGP, _,_ = self.GPFromDict(self.mergeLastN(self.Dicts+[D_temp],1))
#     168                 Q = self.Qestimate(x,y,VGP)
#
# /home/nishad/Documents/simple-RL/gp_rtdp_bq.py in TrialRecurse(x, y, VGP)
#     164                 print maxa
#     165                 (sx,sy) = self.computeResult(x,y,maxa)
# --> 166                 TrialRecurse(sx,sy,VGP)
#     167                 VGP, _,_ = self.GPFromDict(self.mergeLastN(self.Dicts+[D_temp],1))
#     168                 Q = self.Qestimate(x,y,VGP)
#
# /home/nishad/Documents/simple-RL/gp_rtdp_bq.py in TrialRecurse(x, y, VGP)
#     164                 print maxa
#     165                 (sx,sy) = self.computeResult(x,y,maxa)
# --> 166                 TrialRecurse(sx,sy,VGP)
#     167                 VGP, _,_ = self.GPFromDict(self.mergeLastN(self.Dicts+[D_temp],1))
#     168                 Q = self.Qestimate(x,y,VGP)
#
# /home/nishad/Documents/simple-RL/gp_rtdp_bq.py in TrialRecurse(x, y, VGP)
#     164                 print maxa
#     165                 (sx,sy) = self.computeResult(x,y,maxa)
# --> 166                 TrialRecurse(sx,sy,VGP)
#     167                 VGP, _,_ = self.GPFromDict(self.mergeLastN(self.Dicts+[D_temp],1))
#     168                 Q = self.Qestimate(x,y,VGP)
#
# /home/nishad/Documents/simple-RL/gp_rtdp_bq.py in TrialRecurse(x, y, VGP)
#     164                 print maxa
#     165                 (sx,sy) = self.computeResult(x,y,maxa)
# --> 166                 TrialRecurse(sx,sy,VGP)
#     167                 VGP, _,_ = self.GPFromDict(self.mergeLastN(self.Dicts+[D_temp],1))
#     168                 Q = self.Qestimate(x,y,VGP)
#
# /home/nishad/Documents/simple-RL/gp_rtdp_bq.py in TrialRecurse(x, y, VGP)
#     164                 print maxa
#     165                 (sx,sy) = self.computeResult(x,y,maxa)
# --> 166                 TrialRecurse(sx,sy,VGP)
#     167                 VGP, _,_ = self.GPFromDict(self.mergeLastN(self.Dicts+[D_temp],1))
#     168                 Q = self.Qestimate(x,y,VGP)
#
# /home/nishad/Documents/simple-RL/gp_rtdp_bq.py in TrialRecurse(x, y, VGP)
#     164                 print maxa
#     165                 (sx,sy) = self.computeResult(x,y,maxa)
# --> 166                 TrialRecurse(sx,sy,VGP)
#     167                 VGP, _,_ = self.GPFromDict(self.mergeLastN(self.Dicts+[D_temp],1))
#     168                 Q = self.Qestimate(x,y,VGP)
#
# /home/nishad/Documents/simple-RL/gp_rtdp_bq.py in TrialRecurse(x, y, VGP)
#     164                 print maxa
#     165                 (sx,sy) = self.computeResult(x,y,maxa)
# --> 166                 TrialRecurse(sx,sy,VGP)
#     167                 VGP, _,_ = self.GPFromDict(self.mergeLastN(self.Dicts+[D_temp],1))
#     168                 Q = self.Qestimate(x,y,VGP)
#
# /home/nishad/Documents/simple-RL/gp_rtdp_bq.py in TrialRecurse(x, y, VGP)
#     164                 print maxa
#     165                 (sx,sy) = self.computeResult(x,y,maxa)
# --> 166                 TrialRecurse(sx,sy,VGP)
#     167                 VGP, _,_ = self.GPFromDict(self.mergeLastN(self.Dicts+[D_temp],1))
#     168                 Q = self.Qestimate(x,y,VGP)
#
# /home/nishad/Documents/simple-RL/gp_rtdp_bq.py in TrialRecurse(x, y, VGP)
#     164                 print maxa
#     165                 (sx,sy) = self.computeResult(x,y,maxa)
# --> 166                 TrialRecurse(sx,sy,VGP)
#     167                 VGP, _,_ = self.GPFromDict(self.mergeLastN(self.Dicts+[D_temp],1))
#     168                 Q = self.Qestimate(x,y,VGP)
#
# /home/nishad/Documents/simple-RL/gp_rtdp_bq.py in TrialRecurse(x, y, VGP)
#     164                 print maxa
#     165                 (sx,sy) = self.computeResult(x,y,maxa)
# --> 166                 TrialRecurse(sx,sy,VGP)
#     167                 VGP, _,_ = self.GPFromDict(self.mergeLastN(self.Dicts+[D_temp],1))
#     168                 Q = self.Qestimate(x,y,VGP)
#
# /home/nishad/Documents/simple-RL/gp_rtdp_bq.py in TrialRecurse(x, y, VGP)
#     164                 print maxa
#     165                 (sx,sy) = self.computeResult(x,y,maxa)
# --> 166                 TrialRecurse(sx,sy,VGP)
#     167                 VGP, _,_ = self.GPFromDict(self.mergeLastN(self.Dicts+[D_temp],1))
#     168                 Q = self.Qestimate(x,y,VGP)
#
# /home/nishad/Documents/simple-RL/gp_rtdp_bq.py in TrialRecurse(x, y, VGP)
#     164                 print maxa
#     165                 (sx,sy) = self.computeResult(x,y,maxa)
# --> 166                 TrialRecurse(sx,sy,VGP)
#     167                 VGP, _,_ = self.GPFromDict(self.mergeLastN(self.Dicts+[D_temp],1))
#     168                 Q = self.Qestimate(x,y,VGP)
#
# /home/nishad/Documents/simple-RL/gp_rtdp_bq.py in TrialRecurse(x, y, VGP)
#     164                 print maxa
#     165                 (sx,sy) = self.computeResult(x,y,maxa)
# --> 166                 TrialRecurse(sx,sy,VGP)
#     167                 VGP, _,_ = self.GPFromDict(self.mergeLastN(self.Dicts+[D_temp],1))
#     168                 Q = self.Qestimate(x,y,VGP)
#
# /home/nishad/Documents/simple-RL/gp_rtdp_bq.py in TrialRecurse(x, y, VGP)
#     160                 if self.inGoal(x,y):
#     161                     return
# --> 162                 Q = self.Qestimate(x,y,VGP)
#     163                 maxa = max(Q, key=Q.get)
#     164                 print maxa
#
# /home/nishad/Documents/simple-RL/gp_rtdp_bq.py in Qestimate(self, x, y, V_prev)
#     111             tot = 0
#     112             for i in range(self.ATTEMPTS):
# --> 113                 result = self.computeResult(x,y,a)
#     114                 resultState= np.array([result])
#     115                 tot += (0.95*V_prev.predict(resultState)[0][0][0] if not self.inGoal(*result) else 0) + self.rewardFunction(*result)
#
# /home/nishad/Documents/simple-RL/gp_rtdp_bq.py in computeResult(self, x, y, angle)
#      55         if not self.inWorld(newX,newY):
#      56             return x,y
# ---> 57         return self.squash(newX,newY)
#      58
#      59     def computeUnsquashedResult(self,x,y,angle):
#
# /home/nishad/Documents/simple-RL/gp_rtdp_bq.py in squash(self, x, y)
#      46
#      47     def squash(self,x,y):
# ---> 48         if self.inWorld(x,y):
#      49             return (x,y)
#      50         else:
#
# /home/nishad/Documents/simple-RL/gp_rtdp_bq.py in inWorld(self, x, y)
#      38
#      39     def inWorld(self,x,y):
# ---> 40         if self.inObstacle(x,y):
#      41             return False
#      42         return self.inBounds(x,y)
#
# /home/nishad/Documents/simple-RL/gp_rtdp_bq.py in inObstacle(self, x, y)
#      32
#      33     def inObstacle(self,x,y):
# ---> 34         return polygons.contains_points(self.context, [(x,y)])[0]
#      35
#      36     def inBounds(self,x,y):
#
# /home/nishad/Documents/push-pybullet/nish/local/lib/python2.7/site-packages/polygons/__init__.pyc in contains_points(context, points)
#     133                                   x_coordinates_p,
#     134                                   y_coordinates_p,
# --> 135                                   contains_points_p)
#     136
#     137     return contains_points_np.tolist()
#
# KeyboardInterrupt:

# %%
import matplotlib.pyplot as plt
import matplotlib.colors as colors

rx = [0,30]
ry = [0,30]
a = np.full((rx[1]-rx[0],ry[1]-ry[0]),0.0)
for i in range(rx[0],rx[1]):
    for j in range(ry[0],ry[1]):
        a[i-rx[0],j-ry[0]] = p.VPGS[-1].predict(np.array([[i,j]]))[0][0][0]
if a.min()< 0:
    a += -(a.min())
a+=.001
plt.imshow(a, cmap='hot',  norm=colors.LogNorm(vmin=a.min(), vmax=a.max()), interpolation='nearest')
# l =  p.VPGS[-1][1].keys()
# pl.plot([i[0] for i in l], [i[1] for i in l], 'ro')
plt.show()

# %%
print p.VPGS[-1].predict(np.array([[25.787532616677595, 25.738565118287685]]))
# print p.Dicts
# print p.VPGS[-1]
# Out:
# (array([[2.76947643e-285]]), array([[2.]]))

# %%
path = p.testValueFunction(p.VPGS[-1],30.0,30.0,70)

# %%
p.VPGS[-1].plot()

# %%
import numpy as np
import pylab as pl
from matplotlib import collections  as mc
import matplotlib.patches as patches
lines = []
for i in xrange(len(path)-20):
    lines.append([path[i],path[i+1]])

obstacles = []
for obs in p.obstacles:
    rec = patches.Rectangle((obs[0][0],obs[0][1]),obs[2][0]-obs[0][0],obs[2][1]-obs[0][1],linewidth=1,edgecolor='r',facecolor='none')
    obstacles.append(rec)


lc = mc.LineCollection(lines,linewidths=2)
fig, ax = pl.subplots()
# pl.plot([i[0] for i in path], [i[1] for i in path], 'ro')
for rec in obstacles:
    ax.add_patch(rec)

ax.add_collection(lc)
ax.autoscale()
ax.invert_yaxis()
ax.margins(0.1)

# %%
p.computeDeterministicTransition(30.0,30.0,3.9554314190044186)
# Out:
# (29.3132870090344, 29.27307134597742)

# %%
np.random.multivariate_normal([0,0], [[0.1,0],[0,0.1]])
# Out:
# array([ 0.01884862, -0.0162865 ])

# %%
len(p.VPGS)
# Out:
# 7

# %%
integrate(p.VPGS[-1],4.0, 4.0,0.1)
# Out:
# (916.4493590139703, array([[0.71339208]]))

# %%
import polygons

# %%
polygons.

# %%
a.p
