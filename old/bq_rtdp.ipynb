# 0.0 (16.298604114144954, 7.940540240913078) (16.153846153846153, 8.076923076923077) 3296.6791112412
# 4.844019957490407 (17.094972939255445, 8.663782202805669) (17.23076923076923, 8.615384615384615) 3238.0453481723407
# 4.352597642962395 (17.5072468450453, 10.25370020988458) (17.76923076923077, 10.23076923076923) 3159.3596500243325
# 4.457902424646969 (17.951082991974367, 11.190173760471847) (17.76923076923077, 11.307692307692307) 2908.10770886069
# 4.141988079593246 (17.752031740352074, 12.790066983757637) (17.76923076923077, 12.923076923076923) 2713.219752136414
# 4.2472928612778205 (17.605403880544714, 13.503735777474311) (17.76923076923077, 13.461538461538462) 2665.945474863626
# 4.598308800226401 (17.690785426187507, 13.76268994817612) (17.76923076923077, 14.0) 2575.600524346955
# 4.844019957490407 (17.891535901657114, 14.610028718341182) (17.76923076923077, 14.538461538461538) 2385.4019631628867
# 4.457902424646969 (17.57024184030908, 15.172896524985877) (17.76923076923077, 15.076923076923077) 2330.868737879657
# 4.141988079593246 (17.9156307326214, 16.835878724969987) (17.76923076923077, 16.69230769230769) 2186.907394484183
# 4.808918363595549 (18.237595209905933, 17.83369241886302) (18.307692307692307, 17.76923076923077) 1976.6312017768582
# 4.2472928612778205 (18.80067693754796, 18.879732658236883) (18.846153846153847, 18.846153846153847) 974.0267341677958
# 4.071784891803531 (19.0, 19.0) (18.846153846153847, 18.846153846153847) 822.2661191195353
# ITERATION 5
# (19.0, 19.0)
# (18.289386242887915, 18.679959617116943)
# (17.055654341478274, 17.537682544757796)
# (16.403109043941605, 17.221911396559996)
# (15.791313324128131, 17.579921357103757)
# (14.443576952200846, 17.59704229478131)
# (13.76698428630854, 18.066654919478523)
# (12.928960425331042, 17.238679462269396)
# (11.82866198403997, 17.036911383644874)
# (10.950176505224027, 17.062445558680327)
# (9.8525077324936, 17.203593916330384)
# (9.222425442643658, 17.876007282504364)
# (8.215481556458982, 17.685726267742393)
# (7.262843671686661, 17.24581193680095)
# (6.55208217871597, 17.0214394446683)
# (5.720912609118276, 17.253234116771505)
# (4.526716055384073, 17.70631235081296)
# (3.3670190478401683, 17.461763790661536)
# (3.035716137990263, 16.801173184446505)
# (3.4927455716806506, 16.007114603722556)
# (2.673389954856518, 15.72160991468704)
# (3.0837693519929887, 14.664031148667329)
# (2.9179045374859323, 13.560784473415337)
# (1.9082448087379307, 12.686340207148223)
# (2.896506143160769, 12.02966111789087)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/nishad/Documents/simple-RL/robotworld.py in <module>()
#     261
#     262 p = PWorld()
# --> 263 p.RTDP()
#
# /home/nishad/Documents/simple-RL/robotworld.py in RTDP(self)
#     198         for i in range(self.ITERS):
#     199             print "ITERATION %d" % (i)
# --> 200             TrialRecurseWrapper(self.startX,self.startY,VGP)
#     201             self.Dicts.append(D)
#     202             VGP, _,_ = self.GPFromDict(D)
#
# /home/nishad/Documents/simple-RL/robotworld.py in TrialRecurseWrapper(ax, ay, VGP)
#     194                 D[(newx,newy)] = Q[maxa]
#     195                 print maxa, (x,y),(newx,newy), Q[maxa]
# --> 196             TrialRecurse(ax,ay,VGP)
#     197
#     198         for i in range(self.ITERS):
#
# /home/nishad/Documents/simple-RL/robotworld.py in TrialRecurse(x, y, VGP, hit)
#     182                 (sx,sy),hit = self.transition(x,y,maxa)
#     183
# --> 184                 TrialRecurse(sx,sy,VGP,hit)
#     185
#     186                 VGP, _,_ = self.GPFromDict(D)
#
# /home/nishad/Documents/simple-RL/robotworld.py in TrialRecurse(x, y, VGP, hit)
#     182                 (sx,sy),hit = self.transition(x,y,maxa)
#     183
# --> 184                 TrialRecurse(sx,sy,VGP,hit)
#     185
#     186                 VGP, _,_ = self.GPFromDict(D)
#
# /home/nishad/Documents/simple-RL/robotworld.py in TrialRecurse(x, y, VGP, hit)
#     182                 (sx,sy),hit = self.transition(x,y,maxa)
#     183
# --> 184                 TrialRecurse(sx,sy,VGP,hit)
#     185
#     186                 VGP, _,_ = self.GPFromDict(D)
#
# /home/nishad/Documents/simple-RL/robotworld.py in TrialRecurse(x, y, VGP, hit)
#     182                 (sx,sy),hit = self.transition(x,y,maxa)
#     183
# --> 184                 TrialRecurse(sx,sy,VGP,hit)
#     185
#     186                 VGP, _,_ = self.GPFromDict(D)
#
# /home/nishad/Documents/simple-RL/robotworld.py in TrialRecurse(x, y, VGP, hit)
#     182                 (sx,sy),hit = self.transition(x,y,maxa)
#     183
# --> 184                 TrialRecurse(sx,sy,VGP,hit)
#     185
#     186                 VGP, _,_ = self.GPFromDict(D)
#
# /home/nishad/Documents/simple-RL/robotworld.py in TrialRecurse(x, y, VGP, hit)
#     182                 (sx,sy),hit = self.transition(x,y,maxa)
#     183
# --> 184                 TrialRecurse(sx,sy,VGP,hit)
#     185
#     186                 VGP, _,_ = self.GPFromDict(D)
#
# /home/nishad/Documents/simple-RL/robotworld.py in TrialRecurse(x, y, VGP, hit)
#     182                 (sx,sy),hit = self.transition(x,y,maxa)
#     183
# --> 184                 TrialRecurse(sx,sy,VGP,hit)
#     185
#     186                 VGP, _,_ = self.GPFromDict(D)
#
# /home/nishad/Documents/simple-RL/robotworld.py in TrialRecurse(x, y, VGP, hit)
#     182                 (sx,sy),hit = self.transition(x,y,maxa)
#     183
# --> 184                 TrialRecurse(sx,sy,VGP,hit)
#     185
#     186                 VGP, _,_ = self.GPFromDict(D)
#
# /home/nishad/Documents/simple-RL/robotworld.py in TrialRecurse(x, y, VGP, hit)
#     182                 (sx,sy),hit = self.transition(x,y,maxa)
#     183
# --> 184                 TrialRecurse(sx,sy,VGP,hit)
#     185
#     186                 VGP, _,_ = self.GPFromDict(D)
#
# /home/nishad/Documents/simple-RL/robotworld.py in TrialRecurse(x, y, VGP, hit)
#     182                 (sx,sy),hit = self.transition(x,y,maxa)
#     183
# --> 184                 TrialRecurse(sx,sy,VGP,hit)
#     185
#     186                 VGP, _,_ = self.GPFromDict(D)
#
# /home/nishad/Documents/simple-RL/robotworld.py in TrialRecurse(x, y, VGP, hit)
#     182                 (sx,sy),hit = self.transition(x,y,maxa)
#     183
# --> 184                 TrialRecurse(sx,sy,VGP,hit)
#     185
#     186                 VGP, _,_ = self.GPFromDict(D)
#
# /home/nishad/Documents/simple-RL/robotworld.py in TrialRecurse(x, y, VGP, hit)
#     182                 (sx,sy),hit = self.transition(x,y,maxa)
#     183
# --> 184                 TrialRecurse(sx,sy,VGP,hit)
#     185
#     186                 VGP, _,_ = self.GPFromDict(D)
#
# /home/nishad/Documents/simple-RL/robotworld.py in TrialRecurse(x, y, VGP, hit)
#     182                 (sx,sy),hit = self.transition(x,y,maxa)
#     183
# --> 184                 TrialRecurse(sx,sy,VGP,hit)
#     185
#     186                 VGP, _,_ = self.GPFromDict(D)
#
# /home/nishad/Documents/simple-RL/robotworld.py in TrialRecurse(x, y, VGP, hit)
#     182                 (sx,sy),hit = self.transition(x,y,maxa)
#     183
# --> 184                 TrialRecurse(sx,sy,VGP,hit)
#     185
#     186                 VGP, _,_ = self.GPFromDict(D)
#
# /home/nishad/Documents/simple-RL/robotworld.py in TrialRecurse(x, y, VGP, hit)
#     182                 (sx,sy),hit = self.transition(x,y,maxa)
#     183
# --> 184                 TrialRecurse(sx,sy,VGP,hit)
#     185
#     186                 VGP, _,_ = self.GPFromDict(D)
#
# /home/nishad/Documents/simple-RL/robotworld.py in TrialRecurse(x, y, VGP, hit)
#     182                 (sx,sy),hit = self.transition(x,y,maxa)
#     183
# --> 184                 TrialRecurse(sx,sy,VGP,hit)
#     185
#     186                 VGP, _,_ = self.GPFromDict(D)
#
# /home/nishad/Documents/simple-RL/robotworld.py in TrialRecurse(x, y, VGP, hit)
#     182                 (sx,sy),hit = self.transition(x,y,maxa)
#     183
# --> 184                 TrialRecurse(sx,sy,VGP,hit)
#     185
#     186                 VGP, _,_ = self.GPFromDict(D)
#
# /home/nishad/Documents/simple-RL/robotworld.py in TrialRecurse(x, y, VGP, hit)
#     182                 (sx,sy),hit = self.transition(x,y,maxa)
#     183
# --> 184                 TrialRecurse(sx,sy,VGP,hit)
#     185
#     186                 VGP, _,_ = self.GPFromDict(D)
#
# /home/nishad/Documents/simple-RL/robotworld.py in TrialRecurse(x, y, VGP, hit)
#     182                 (sx,sy),hit = self.transition(x,y,maxa)
#     183
# --> 184                 TrialRecurse(sx,sy,VGP,hit)
#     185
#     186                 VGP, _,_ = self.GPFromDict(D)
#
# /home/nishad/Documents/simple-RL/robotworld.py in TrialRecurse(x, y, VGP, hit)
#     182                 (sx,sy),hit = self.transition(x,y,maxa)
#     183
# --> 184                 TrialRecurse(sx,sy,VGP,hit)
#     185
#     186                 VGP, _,_ = self.GPFromDict(D)
#
# /home/nishad/Documents/simple-RL/robotworld.py in TrialRecurse(x, y, VGP, hit)
#     182                 (sx,sy),hit = self.transition(x,y,maxa)
#     183
# --> 184                 TrialRecurse(sx,sy,VGP,hit)
#     185
#     186                 VGP, _,_ = self.GPFromDict(D)
#
# /home/nishad/Documents/simple-RL/robotworld.py in TrialRecurse(x, y, VGP, hit)
#     182                 (sx,sy),hit = self.transition(x,y,maxa)
#     183
# --> 184                 TrialRecurse(sx,sy,VGP,hit)
#     185
#     186                 VGP, _,_ = self.GPFromDict(D)
#
# /home/nishad/Documents/simple-RL/robotworld.py in TrialRecurse(x, y, VGP, hit)
#     182                 (sx,sy),hit = self.transition(x,y,maxa)
#     183
# --> 184                 TrialRecurse(sx,sy,VGP,hit)
#     185
#     186                 VGP, _,_ = self.GPFromDict(D)
#
# /home/nishad/Documents/simple-RL/robotworld.py in TrialRecurse(x, y, VGP, hit)
#     182                 (sx,sy),hit = self.transition(x,y,maxa)
#     183
# --> 184                 TrialRecurse(sx,sy,VGP,hit)
#     185
#     186                 VGP, _,_ = self.GPFromDict(D)
#
# /home/nishad/Documents/simple-RL/robotworld.py in TrialRecurse(x, y, VGP, hit)
#     178                 if self.in_goal(x,y) or hit:
#     179                     return
# --> 180                 Q = self.q_estimate(x,y,VGP)
#     181                 maxa = max(Q, key=Q.get)
#     182                 (sx,sy),hit = self.transition(x,y,maxa)
#
# /home/nishad/Documents/simple-RL/robotworld.py in q_estimate(self, x, y, V_prev)
#     109                 result,_ = self.transition(x,y,a)
#     110                 resultState= np.array([result])
# --> 111                 val =  (0.9*V_prev.predict(resultState)[0][0][0]) + self.reward(*result)
#     112                 tot += val
#     113             Q[a] = tot / float(self.ATTEMPTS)
#
# /home/nishad/Documents/push-pybullet/nish/local/lib/python2.7/site-packages/GPy/core/gp.pyc in predict(self, Xnew, full_cov, Y_metadata, kern, likelihood, include_likelihood)
#     321
#     322         # Predict the latent function values
# --> 323         mean, var = self._raw_predict(Xnew, full_cov=full_cov, kern=kern)
#     324
#     325         if include_likelihood:
#
# /home/nishad/Documents/push-pybullet/nish/local/lib/python2.7/site-packages/GPy/core/gp.pyc in _raw_predict(self, Xnew, full_cov, kern)
#     278             \Sigma := \texttt{Likelihood.variance / Approximate likelihood covariance}
#     279         """
# --> 280         mu, var = self.posterior._raw_predict(kern=self.kern if kern is None else kern, Xnew=Xnew, pred_var=self._predictive_variable, full_cov=full_cov)
#     281         if self.mean_function is not None:
#     282             mu += self.mean_function.f(Xnew)
#
# /home/nishad/Documents/push-pybullet/nish/local/lib/python2.7/site-packages/GPy/inference/latent_function_inference/posterior.pyc in _raw_predict(self, kern, Xnew, pred_var, full_cov)
#     286             Kxx = kern.Kdiag(Xnew)
#     287             if self._woodbury_chol.ndim == 2:
# --> 288                 tmp = dtrtrs(self._woodbury_chol, Kx)[0]
#     289                 var = (Kxx - np.square(tmp).sum(0))[:,None]
#     290             elif self._woodbury_chol.ndim == 3: # Missing data
#
# /home/nishad/Documents/push-pybullet/nish/local/lib/python2.7/site-packages/GPy/util/linalg.pyc in dtrtrs(A, B, lower, trans, unitdiag)
#     109     A = np.asfortranarray(A)
#     110     #Note: B does not seem to need to be F ordered!
# --> 111     return lapack.dtrtrs(A, B, lower=lower, trans=trans, unitdiag=unitdiag)
#     112
#     113 def dpotrs(A, B, lower=1):
#
# KeyboardInterrupt:

# %%
import matplotlib.pyplot as plt
import matplotlib.colors as colors

rx = [0,30]
ry = [0,30]
a = np.full((rx[1]-rx[0],ry[1]-ry[0]),0.0)
for i in range(rx[0],rx[1]):
    for j in range(ry[0],ry[1]):
        a[i-rx[0],j-ry[0]] = p.VPGS[-1].predict(np.array([[i,j]]))[0][0][0]
if a.min()< 0:
    a += -(a.min())
a+=.001
plt.imshow(a, cmap='hot',  norm=colors.LogNorm(vmin=a.min(), vmax=a.max()), interpolation='nearest')
# l =  p.VPGS[-1][1].keys()
# pl.plot([i[0] for i in l], [i[1] for i in l], 'ro')
plt.show()

# %%
Q = {}
x,y = 16.0,16.0
for a in p.sample_n(180):
    nx,ny = p.angle_delta(x,y,a)
    temp = p.integrate(p.VPGS[-1],nx,ny,0.05)
    Q[a] = (p.integrate(p.RGP,nx,ny,0.05)[0] + 0.9*temp[0],temp[1])

# %%
path = p.testValueFunction(p.VPGS[-1],20.0,10.0,40)
# Out:
# 20.0 10.0
# 18.51850658432514 9.880313575415983
# 17.366783733739158 9.247088265249568
# 16.975092262439848 8.73782565595381
# 17.21898292863483 7.721903398150243
# 17.451243626465185 6.578866593493957
# 17.209553269886857 6.039424395127759
# 17.01124731829634 4.946352095126897
# 16.611143811441952 3.9489595240196955
# 16.485444946856415 3.127850505708447
# 15.620635439470448 2.970224806213919
# 14.367228314343876 2.432578797611755
# 14.229610985883529 2.216287319556206
# 13.644626603148003 2.7593467728686374
# 13.186057349434085 2.253551660216684
# 13.533657886748191 3.0402625081909775
# 13.269119001730882 2.1837097902011413
# 12.316879853308874 2.074620856116172
# 10.935182048254775 2.834532850606866
# 9.131691804892736 2.4175026956439

# %%
p.VPGS[5].plot()

# %%
import numpy as np
import pylab as pl
from matplotlib import collections  as mc
import matplotlib.patches as patches
lines = []
for i in xrange(len(path)-1):
    lines.append([path[i],path[i+1]])

obstacles = []
for obs in p.obstacles:
    rec = patches.Rectangle((obs.bounds[0],obs.bounds[1]),obs.bounds[2]-obs.bounds[0],obs.bounds[3]-obs.bounds[1],linewidth=1,edgecolor='r',facecolor='none')
    obstacles.append(rec)


lc = mc.LineCollection(lines,linewidths=2)
fig, ax = pl.subplots()
# pl.plot([i[0] for i in path], [i[1] for i in path], 'ro')
for rec in obstacles:
    ax.add_patch(rec)

ax.add_collection(lc)
ax.autoscale()
ax.invert_yaxis()
ax.margins(0.1)

# %%
p.RGP.plot()

# %%
lists = sorted(Q.items()) # sorted by key, return a list of tuples
x = map(lambda x: x[0],lists)
y = map(lambda x: x[1][0],lists)
e = map(lambda x: x[1][1],lists)
plt.errorbar(x, y, yerr=e, fmt='o')
plt.show()

# %%
old = p.VPGS
