# (23.89862396688997, 19.523091548044878)
# (23.36086247400864, 19.124094540387826)
# (22.014687711485642, 18.911121337691785)
# (21.172983084231625, 18.36763064647995)
# (20.261576934299114, 17.778420579461983)
# (20.07120068497119, 17.174156684002615)
# (19.455049715280705, 16.780061950657185)
# (18.951860042780318, 16.26181596828235)
# (17.711679871062177, 16.205889573872387)
# (16.50902293915867, 15.922333568409462)
# (15.372725236804687, 15.563513700199277)
# (14.530667597568602, 14.386115690523935)
# (14.188415066673327, 13.376425267783786)
# (13.531168885681744, 12.43266181104744)
# (13.421451021652796, 11.597727457151466)
# (13.239170808049659, 10.868917682682694)
# (12.59031452721352, 9.94668919444137)
# (11.996205191487359, 9.516357613827601)
# (11.512887710361381, 8.78575669534752)
# (10.423744021304179, 7.979608581069425)
# (10.823932621539099, 7.1641981924100175)
# (10.932985668527095, 6.301660017067609)
# (10.746238975738807, 5.641278181724623)
# (10.13909297538407, 4.764829076728499)
# (9.461089699506424, 4.085029036354396)
# (8.536570902146176, 4.033944208063535)
# (7.491373319840144, 3.975559919481487)
# (6.419330062082462, 3.8715374736145325)
# (5.63645707879722, 3.8867385438202806)
# (4.644831183974399, 3.6831118197358816)
# 3.8015911102263042 (5.63645707879722, 3.8867385438202806) 26810.35887915179
# 3.326392221448016 (6.419330062082462, 3.8715374736145325) 16329.825904729387
# 3.1679925918552536 (7.491373319840144, 3.975559919481487) 10933.091133760074
# 2.851193332669728 (8.536570902146176, 4.033944208063535) 8429.0533265101
# 2.7983934561388075 (9.461089699506424, 4.085029036354396) 7184.541528227727
# 3.6959913571644627 (10.13909297538407, 4.764829076728499) 6243.391228729031
# 5.385587406153931 (10.746238975738807, 5.641278181724623) 5567.312779352127
# 5.91358617146314 (10.932985668527095, 6.301660017067609) 5484.544041620511
# 5.807986418401298 (10.823932621539099, 7.1641981924100175) 5230.120521309385
# 6.019185924524982 (10.423744021304179, 7.979608581069425) 4850.206763314092
# 5.068788146968406 (11.512887710361381, 8.78575669534752) 5004.536412868759
# 5.068788146968406 (11.996205191487359, 9.516357613827601) 4893.918015402045
# 4.593589258190118 (12.59031452721352, 9.94668919444137) 4746.689385177832
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/nishad/Documents/simple-RL/robotworld.py in <module>()
#     277
#     278 p = PWorld()
# --> 279 p.RTDP()
#
# /home/nishad/Documents/simple-RL/robotworld.py in RTDP(self)
#     176         for i in range(self.ITERS):
#     177             print "ITERATION %d" % (i)
# --> 178             TrialRecurseWrapper(self.startX,self.startY,VGP)
#     179             self.Dicts.append(D)
#     180             # VGP, _,_ = self.GPFromDict(D)
#
# /home/nishad/Documents/simple-RL/robotworld.py in TrialRecurseWrapper(ax, ay, VGP)
#     172                 else:
#     173                     D[(newx,newy)] = Q[maxa]
# --> 174             TrialRecurse(ax,ay,VGP)
#     175
#     176         for i in range(self.ITERS):
#
# /home/nishad/Documents/simple-RL/robotworld.py in TrialRecurse(x, y, VGP, hit)
#     162                 # print maxa, Q[maxa]
#     163                 (sx,sy),hit = self.transition(x,y,maxa)
# --> 164                 TrialRecurse(sx,sy,VGP,hit)
#     165                 VGP, _,_ = self.GPFromDict(D)
#     166                 Q = self.q_estimate(x,y,VGP)
#
# /home/nishad/Documents/simple-RL/robotworld.py in TrialRecurse(x, y, VGP, hit)
#     162                 # print maxa, Q[maxa]
#     163                 (sx,sy),hit = self.transition(x,y,maxa)
# --> 164                 TrialRecurse(sx,sy,VGP,hit)
#     165                 VGP, _,_ = self.GPFromDict(D)
#     166                 Q = self.q_estimate(x,y,VGP)
#
# /home/nishad/Documents/simple-RL/robotworld.py in TrialRecurse(x, y, VGP, hit)
#     162                 # print maxa, Q[maxa]
#     163                 (sx,sy),hit = self.transition(x,y,maxa)
# --> 164                 TrialRecurse(sx,sy,VGP,hit)
#     165                 VGP, _,_ = self.GPFromDict(D)
#     166                 Q = self.q_estimate(x,y,VGP)
#
# /home/nishad/Documents/simple-RL/robotworld.py in TrialRecurse(x, y, VGP, hit)
#     162                 # print maxa, Q[maxa]
#     163                 (sx,sy),hit = self.transition(x,y,maxa)
# --> 164                 TrialRecurse(sx,sy,VGP,hit)
#     165                 VGP, _,_ = self.GPFromDict(D)
#     166                 Q = self.q_estimate(x,y,VGP)
#
# /home/nishad/Documents/simple-RL/robotworld.py in TrialRecurse(x, y, VGP, hit)
#     162                 # print maxa, Q[maxa]
#     163                 (sx,sy),hit = self.transition(x,y,maxa)
# --> 164                 TrialRecurse(sx,sy,VGP,hit)
#     165                 VGP, _,_ = self.GPFromDict(D)
#     166                 Q = self.q_estimate(x,y,VGP)
#
# /home/nishad/Documents/simple-RL/robotworld.py in TrialRecurse(x, y, VGP, hit)
#     162                 # print maxa, Q[maxa]
#     163                 (sx,sy),hit = self.transition(x,y,maxa)
# --> 164                 TrialRecurse(sx,sy,VGP,hit)
#     165                 VGP, _,_ = self.GPFromDict(D)
#     166                 Q = self.q_estimate(x,y,VGP)
#
# /home/nishad/Documents/simple-RL/robotworld.py in TrialRecurse(x, y, VGP, hit)
#     162                 # print maxa, Q[maxa]
#     163                 (sx,sy),hit = self.transition(x,y,maxa)
# --> 164                 TrialRecurse(sx,sy,VGP,hit)
#     165                 VGP, _,_ = self.GPFromDict(D)
#     166                 Q = self.q_estimate(x,y,VGP)
#
# /home/nishad/Documents/simple-RL/robotworld.py in TrialRecurse(x, y, VGP, hit)
#     162                 # print maxa, Q[maxa]
#     163                 (sx,sy),hit = self.transition(x,y,maxa)
# --> 164                 TrialRecurse(sx,sy,VGP,hit)
#     165                 VGP, _,_ = self.GPFromDict(D)
#     166                 Q = self.q_estimate(x,y,VGP)
#
# /home/nishad/Documents/simple-RL/robotworld.py in TrialRecurse(x, y, VGP, hit)
#     162                 # print maxa, Q[maxa]
#     163                 (sx,sy),hit = self.transition(x,y,maxa)
# --> 164                 TrialRecurse(sx,sy,VGP,hit)
#     165                 VGP, _,_ = self.GPFromDict(D)
#     166                 Q = self.q_estimate(x,y,VGP)
#
# /home/nishad/Documents/simple-RL/robotworld.py in TrialRecurse(x, y, VGP, hit)
#     162                 # print maxa, Q[maxa]
#     163                 (sx,sy),hit = self.transition(x,y,maxa)
# --> 164                 TrialRecurse(sx,sy,VGP,hit)
#     165                 VGP, _,_ = self.GPFromDict(D)
#     166                 Q = self.q_estimate(x,y,VGP)
#
# /home/nishad/Documents/simple-RL/robotworld.py in TrialRecurse(x, y, VGP, hit)
#     162                 # print maxa, Q[maxa]
#     163                 (sx,sy),hit = self.transition(x,y,maxa)
# --> 164                 TrialRecurse(sx,sy,VGP,hit)
#     165                 VGP, _,_ = self.GPFromDict(D)
#     166                 Q = self.q_estimate(x,y,VGP)
#
# /home/nishad/Documents/simple-RL/robotworld.py in TrialRecurse(x, y, VGP, hit)
#     162                 # print maxa, Q[maxa]
#     163                 (sx,sy),hit = self.transition(x,y,maxa)
# --> 164                 TrialRecurse(sx,sy,VGP,hit)
#     165                 VGP, _,_ = self.GPFromDict(D)
#     166                 Q = self.q_estimate(x,y,VGP)
#
# /home/nishad/Documents/simple-RL/robotworld.py in TrialRecurse(x, y, VGP, hit)
#     162                 # print maxa, Q[maxa]
#     163                 (sx,sy),hit = self.transition(x,y,maxa)
# --> 164                 TrialRecurse(sx,sy,VGP,hit)
#     165                 VGP, _,_ = self.GPFromDict(D)
#     166                 Q = self.q_estimate(x,y,VGP)
#
# /home/nishad/Documents/simple-RL/robotworld.py in TrialRecurse(x, y, VGP, hit)
#     162                 # print maxa, Q[maxa]
#     163                 (sx,sy),hit = self.transition(x,y,maxa)
# --> 164                 TrialRecurse(sx,sy,VGP,hit)
#     165                 VGP, _,_ = self.GPFromDict(D)
#     166                 Q = self.q_estimate(x,y,VGP)
#
# /home/nishad/Documents/simple-RL/robotworld.py in TrialRecurse(x, y, VGP, hit)
#     162                 # print maxa, Q[maxa]
#     163                 (sx,sy),hit = self.transition(x,y,maxa)
# --> 164                 TrialRecurse(sx,sy,VGP,hit)
#     165                 VGP, _,_ = self.GPFromDict(D)
#     166                 Q = self.q_estimate(x,y,VGP)
#
# /home/nishad/Documents/simple-RL/robotworld.py in TrialRecurse(x, y, VGP, hit)
#     162                 # print maxa, Q[maxa]
#     163                 (sx,sy),hit = self.transition(x,y,maxa)
# --> 164                 TrialRecurse(sx,sy,VGP,hit)
#     165                 VGP, _,_ = self.GPFromDict(D)
#     166                 Q = self.q_estimate(x,y,VGP)
#
# /home/nishad/Documents/simple-RL/robotworld.py in TrialRecurse(x, y, VGP, hit)
#     162                 # print maxa, Q[maxa]
#     163                 (sx,sy),hit = self.transition(x,y,maxa)
# --> 164                 TrialRecurse(sx,sy,VGP,hit)
#     165                 VGP, _,_ = self.GPFromDict(D)
#     166                 Q = self.q_estimate(x,y,VGP)
#
# /home/nishad/Documents/simple-RL/robotworld.py in TrialRecurse(x, y, VGP, hit)
#     162                 # print maxa, Q[maxa]
#     163                 (sx,sy),hit = self.transition(x,y,maxa)
# --> 164                 TrialRecurse(sx,sy,VGP,hit)
#     165                 VGP, _,_ = self.GPFromDict(D)
#     166                 Q = self.q_estimate(x,y,VGP)
#
# /home/nishad/Documents/simple-RL/robotworld.py in TrialRecurse(x, y, VGP, hit)
#     162                 # print maxa, Q[maxa]
#     163                 (sx,sy),hit = self.transition(x,y,maxa)
# --> 164                 TrialRecurse(sx,sy,VGP,hit)
#     165                 VGP, _,_ = self.GPFromDict(D)
#     166                 Q = self.q_estimate(x,y,VGP)
#
# /home/nishad/Documents/simple-RL/robotworld.py in TrialRecurse(x, y, VGP, hit)
#     162                 # print maxa, Q[maxa]
#     163                 (sx,sy),hit = self.transition(x,y,maxa)
# --> 164                 TrialRecurse(sx,sy,VGP,hit)
#     165                 VGP, _,_ = self.GPFromDict(D)
#     166                 Q = self.q_estimate(x,y,VGP)
#
# /home/nishad/Documents/simple-RL/robotworld.py in TrialRecurse(x, y, VGP, hit)
#     162                 # print maxa, Q[maxa]
#     163                 (sx,sy),hit = self.transition(x,y,maxa)
# --> 164                 TrialRecurse(sx,sy,VGP,hit)
#     165                 VGP, _,_ = self.GPFromDict(D)
#     166                 Q = self.q_estimate(x,y,VGP)
#
# /home/nishad/Documents/simple-RL/robotworld.py in TrialRecurse(x, y, VGP, hit)
#     162                 # print maxa, Q[maxa]
#     163                 (sx,sy),hit = self.transition(x,y,maxa)
# --> 164                 TrialRecurse(sx,sy,VGP,hit)
#     165                 VGP, _,_ = self.GPFromDict(D)
#     166                 Q = self.q_estimate(x,y,VGP)
#
# /home/nishad/Documents/simple-RL/robotworld.py in TrialRecurse(x, y, VGP, hit)
#     162                 # print maxa, Q[maxa]
#     163                 (sx,sy),hit = self.transition(x,y,maxa)
# --> 164                 TrialRecurse(sx,sy,VGP,hit)
#     165                 VGP, _,_ = self.GPFromDict(D)
#     166                 Q = self.q_estimate(x,y,VGP)
#
# /home/nishad/Documents/simple-RL/robotworld.py in TrialRecurse(x, y, VGP, hit)
#     162                 # print maxa, Q[maxa]
#     163                 (sx,sy),hit = self.transition(x,y,maxa)
# --> 164                 TrialRecurse(sx,sy,VGP,hit)
#     165                 VGP, _,_ = self.GPFromDict(D)
#     166                 Q = self.q_estimate(x,y,VGP)
#
# /home/nishad/Documents/simple-RL/robotworld.py in TrialRecurse(x, y, VGP, hit)
#     162                 # print maxa, Q[maxa]
#     163                 (sx,sy),hit = self.transition(x,y,maxa)
# --> 164                 TrialRecurse(sx,sy,VGP,hit)
#     165                 VGP, _,_ = self.GPFromDict(D)
#     166                 Q = self.q_estimate(x,y,VGP)
#
# /home/nishad/Documents/simple-RL/robotworld.py in TrialRecurse(x, y, VGP, hit)
#     164                 TrialRecurse(sx,sy,VGP,hit)
#     165                 VGP, _,_ = self.GPFromDict(D)
# --> 166                 Q = self.q_estimate(x,y,VGP)
#     167                 maxa = max(Q, key=Q.get)
#     168                 print maxa, (x,y), Q[maxa]
#
# /home/nishad/Documents/simple-RL/robotworld.py in q_estimate(self, x, y, V_prev)
#      89                 result,_ = self.transition(x,y,a)
#      90                 resultState= np.array([result])
# ---> 91                 val =  (0.9*V_prev.predict(resultState)[0][0][0]) + self.reward(*result)
#      92                 tot += val
#      93             Q[a] = tot / float(self.ATTEMPTS)
#
# /home/nishad/Documents/simple-RL/robotworld.py in reward(self, nx, ny)
#      58         if distToEdge <2.0:
#      59             return (2.0 - distToEdge) * -2000.0
# ---> 60         distToObs, _, _ = self.dist_to_poly(nx,ny,self.obstacles)
#      61         if distToObs <2.0:
#      62             return (2.0 - distToObs) * -2000.0
#
# /home/nishad/Documents/simple-RL/robotworld.py in dist_to_poly(self, x, y, l)
#      37         dist = {}
#      38         for (i,obs) in enumerate(l):
# ---> 39             dist[i] = obs.boundary.distance(Point(x,y))
#      40         return dist,l[i],i
#      41
#
# /home/nishad/Documents/push-pybullet/nish/local/lib/python2.7/site-packages/shapely/geometry/point.pyc in __init__(self, *args)
#      47         BaseGeometry.__init__(self)
#      48         if len(args) > 0:
# ---> 49             self._set_coords(*args)
#      50
#      51     # Coordinate getters and setters
#
# /home/nishad/Documents/push-pybullet/nish/local/lib/python2.7/site-packages/shapely/geometry/point.pyc in _set_coords(self, *args)
#     130             self._geom, self._ndim = geos_point_from_py(args[0])
#     131         else:
# --> 132             self._geom, self._ndim = geos_point_from_py(tuple(args))
#     133
#     134     coords = property(BaseGeometry._get_coords, _set_coords)
#
# /home/nishad/Documents/push-pybullet/nish/local/lib/python2.7/site-packages/shapely/geometry/point.pyc in geos_point_from_py(ob, update_geom, update_ndim)
#     202         ob = list(ob)
#     203
# --> 204     if isinstance(ob[0], tuple):
#     205         coords = ob[0]
#     206     else:
#
# KeyboardInterrupt:

# %%
import matplotlib.pyplot as plt
import matplotlib.colors as colors

rx = [0,30]
ry = [0,30]
a = np.full((rx[1]-rx[0],ry[1]-ry[0]),0.0)
for i in range(rx[0],rx[1]):
    for j in range(ry[0],ry[1]):
        a[i-rx[0],j-ry[0]] = p.VPGS[-1].predict(np.array([[i,j]]))[0][0][0]
if a.min()< 0:
    a += -(a.min())
a+=.001
plt.imshow(a, cmap='hot',  norm=colors.LogNorm(vmin=a.min(), vmax=a.max()), interpolation='nearest')
# l =  p.VPGS[-1][1].keys()
# pl.plot([i[0] for i in l], [i[1] for i in l], 'ro')
plt.show()

# %%
print p.VPGS[-1].predict(np.array([[30.0, 30.0]]))
# Out:
# (array([[nan]]), array([[nan]]))

# %%
path = p.testValueFunction(p.VPGS[-1],30.0,30.0,60)
# Out:
# 30.0 30.0
# 29.100698011491406 29.368231040619847
# 28.195612926937464 28.61898527005848
# 26.893626156511157 28.083920302540943
# 25.875169391879826 27.58551867237629
# 25.22503884939315 26.392161591219995
# 24.70464211799817 25.736074272757428
# 23.490567128503656 25.89253987696329
# 22.84344781751791 25.683759040028935
# 21.84989727190632 25.88326217599005
# 20.724772224374508 26.2125984690676
# 19.86185485079941 25.702033901153097
# 18.84644063212822 24.700049519415572
# 18.346293339564802 24.03094280451164
# 17.477873112861218 23.370459251909324
# 17.061177825453285 22.02820003046149
# 16.703741485297126 21.190962302592027
# 15.828453060102603 20.395271805367592
# 15.435583310133739 19.30369800951357
# 15.243724493438764 18.1526178865328
# 14.288668906655394 17.732396462632334
# 13.20095678117678 16.997131033065532
# 12.46102117095596 15.803863630721377
# 12.210216468302397 15.20870853264103
# 11.389618771430294 14.829760122639373
# 11.051759459165595 13.71778234250488
# 10.759068749731288 12.7446252455473
# 10.406416618022869 11.76050535407635
# 10.55883143374685 10.564025848929312
# 10.31175792031897 9.690588162923984
# 10.749086344432126 8.632260313609535
# 10.952778241798073 7.321062282069742
# 11.07809145425104 5.8801583716659485
# 10.828609604029356 5.04483602877339
# 10.477796806500562 4.260977106305296
# 9.573420918574236 4.037525857502071
# 8.982523207453754 4.058230412732428
# 7.822807988417921 3.6509905241365894
# 6.9806271513108085 3.8172525445175296
# 6.046068095027684 3.7638458603214446
# 5.042856877381818 3.659768614401858
# REACHED IN 40
# 4.308619564797274 3.0892671405347616
# 3.6130896878315637 3.172913447421201
# 2.311020647189111 3.228539192427848
# 3.1995639540975986 2.811535409135769
# 2.5585112709933844 3.7853993545736353
# 3.517688157582321 2.783722436558394
# 2.480609485380886 3.250660601030693
# 3.5767487489978564 3.0419505941912233
# 2.373259296214358 3.3650318603135605
# 3.56904212262004 2.969996603752703
# 2.567245870450682 2.983427368320137
# 3.615956300155766 2.6634221436100427
# 2.669260079341112 3.1596455554763394
# 3.4894363936265216 2.717488120420226
# 3.198306548370669 3.1500015128200025
# 2.758796929383941 2.498306448135665
# 3.5546054941455205 3.202158971253923
# 2.353831941435642 3.008675098454175
# 3.359483153239526 2.7527751045729985

# %%
p.VPGS[-1].plot()

# %%
import numpy as np
import pylab as pl
from matplotlib import collections  as mc
import matplotlib.patches as patches
lines = []
for i in xrange(len(path)-1):
    lines.append([path[i],path[i+1]])

obstacles = []
for obs in p.obstacles:
    rec = patches.Rectangle((obs.bounds[0],obs.bounds[1]),obs.bounds[2]-obs.bounds[0],obs.bounds[3]-obs.bounds[1],linewidth=1,edgecolor='r',facecolor='none')
    obstacles.append(rec)


lc = mc.LineCollection(lines,linewidths=2)
fig, ax = pl.subplots()
# pl.plot([i[0] for i in path], [i[1] for i in path], 'ro')
for rec in obstacles:
    ax.add_patch(rec)

ax.add_collection(lc)
ax.autoscale()
ax.invert_yaxis()
ax.margins(0.1)

# %%
p.computeDeterministicTransition(30.0,30.0,3.9554314190044186)
# Out:
# (29.3132870090344, 29.27307134597742)

# %%
a = p.obstacles[0]

# %%
a.bounds
# Out:
# (5.0, 5.0, 10.0, 10.0)

# %%
integrate(p.VPGS[-1],4.0, 4.0,0.1)
# Out:
# (916.4493590139703, array([[0.71339208]]))

# %%
p.obstacles[0].boundary.distance(Point(0.0,0.0))
# Out:
# 7.0710678118654755

# %%
list(p.obstacles[0].boundary.coords)
# Out:
# [(15.0, 5.0), (15.0, 15.0), (5.0, 15.0), (5.0, 5.0), (15.0, 5.0)]

# %%
p.obstacles[0].boundary.distance(Point(10.0,10.0))
# Out:
# 5.0

# %%
# Out:
# (961, 1)
