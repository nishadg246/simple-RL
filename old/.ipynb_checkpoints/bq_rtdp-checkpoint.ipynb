# (18.10315967238785, 20.9833104123511)
# (17.459249225231936, 20.218209545769792)
# (16.81533877807602, 19.453108679188485)
# (16.1714283309201, 18.68800781260718)
# (15.488036766893552, 17.957955780066108)
# (14.844126319737637, 17.1928549134848)
# (14.284447144953328, 16.364145542647982)
# (13.769283358006431, 15.507053789905878)
# (13.300070812769365, 14.623968523698728)
# (12.697436176390108, 13.82595129641849)
# (11.876186534621795, 13.255382259495335)
# (11.086193356863207, 12.642266626767798)
# (10.812530366791124, 11.680440983594979)
# (10.746578426356429, 10.682618182916974)
# (10.73337884054567, 9.682705301244564)
# (10.720179254734912, 8.682792419572154)
# (10.706979668924154, 7.682879537899743)
# (10.746569227350422, 6.683663511775456)
# (10.628048752178719, 5.690711903203782)
# (10.158836206941652, 4.807626636996631)
# (9.308619071212037, 4.281194474119276)
# (8.33671327728189, 4.045824281178433)
# (7.3398479435546635, 3.9667072386850086)
# (6.342982609827438, 3.887590196191584)
# (5.351681926721641, 3.755973496362191)
# (4.3935523143109725, 3.469638647240078)
# 3.9071908632881462 (5.351681926721641, 3.755973496362191) 25323.156963515477
# 3.5375917275716997 (6.342982609827438, 3.887590196191584) 13683.558776000067
# 3.1679925918552536 (7.3398479435546635, 3.9667072386850086) 10882.587520726463
# 3.0623928387934116 (8.33671327728189, 4.045824281178433) 9434.365836797419
# 3.273592344917095 (9.308619071212037, 4.281194474119276) 8080.81726449563
# 3.5903916041026207 (10.158836206941652, 4.807626636996631) 6443.228161440782
# 5.543987035746694 (10.628048752178719, 5.690711903203782) 6186.292930155978
# 5.279987653092089 (10.746569227350422, 6.683663511775456) 6143.2360542484175
# 5.174387900030248 (10.706979668924154, 7.682879537899743) 6010.360925839885
# 5.068788146968406 (10.720179254734912, 8.682792419572154) 5767.96845766085
# 5.068788146968406 (10.73337884054567, 9.682705301244564) 5438.1840989954835
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/ngothosk/Documents/MIT/simple-rl/robotworld.py in <module>()
#     255
#     256 p = PWorld()
# --> 257 p.RTDP()
#
# /Users/ngothosk/Documents/MIT/simple-rl/robotworld.py in RTDP(self)
#     154         for i in range(self.ITERS):
#     155             print "ITERATION %d" % (i)
# --> 156             TrialRecurseWrapper(self.startX,self.startY,VGP)
#     157             self.Dicts.append(D)
#     158             # VGP, _,_ = self.GPFromDict(D)
#
# /Users/ngothosk/Documents/MIT/simple-rl/robotworld.py in TrialRecurseWrapper(ax, ay, VGP)
#     150                 else:
#     151                     D[(newx,newy)] = Q[maxa]
# --> 152             TrialRecurse(ax,ay,VGP)
#     153
#     154         for i in range(self.ITERS):
#
# /Users/ngothosk/Documents/MIT/simple-rl/robotworld.py in TrialRecurse(x, y, VGP)
#     140                 # print maxa, Q[maxa]
#     141                 (sx,sy),_ = self.transition(x,y,maxa)
# --> 142                 TrialRecurse(sx,sy,VGP)
#     143                 VGP, _,_ = self.GPFromDict(D)
#     144                 Q = self.q_estimate(x,y,VGP)
#
# /Users/ngothosk/Documents/MIT/simple-rl/robotworld.py in TrialRecurse(x, y, VGP)
#     140                 # print maxa, Q[maxa]
#     141                 (sx,sy),_ = self.transition(x,y,maxa)
# --> 142                 TrialRecurse(sx,sy,VGP)
#     143                 VGP, _,_ = self.GPFromDict(D)
#     144                 Q = self.q_estimate(x,y,VGP)
#
# /Users/ngothosk/Documents/MIT/simple-rl/robotworld.py in TrialRecurse(x, y, VGP)
#     140                 # print maxa, Q[maxa]
#     141                 (sx,sy),_ = self.transition(x,y,maxa)
# --> 142                 TrialRecurse(sx,sy,VGP)
#     143                 VGP, _,_ = self.GPFromDict(D)
#     144                 Q = self.q_estimate(x,y,VGP)
#
# /Users/ngothosk/Documents/MIT/simple-rl/robotworld.py in TrialRecurse(x, y, VGP)
#     140                 # print maxa, Q[maxa]
#     141                 (sx,sy),_ = self.transition(x,y,maxa)
# --> 142                 TrialRecurse(sx,sy,VGP)
#     143                 VGP, _,_ = self.GPFromDict(D)
#     144                 Q = self.q_estimate(x,y,VGP)
#
# /Users/ngothosk/Documents/MIT/simple-rl/robotworld.py in TrialRecurse(x, y, VGP)
#     140                 # print maxa, Q[maxa]
#     141                 (sx,sy),_ = self.transition(x,y,maxa)
# --> 142                 TrialRecurse(sx,sy,VGP)
#     143                 VGP, _,_ = self.GPFromDict(D)
#     144                 Q = self.q_estimate(x,y,VGP)
#
# /Users/ngothosk/Documents/MIT/simple-rl/robotworld.py in TrialRecurse(x, y, VGP)
#     140                 # print maxa, Q[maxa]
#     141                 (sx,sy),_ = self.transition(x,y,maxa)
# --> 142                 TrialRecurse(sx,sy,VGP)
#     143                 VGP, _,_ = self.GPFromDict(D)
#     144                 Q = self.q_estimate(x,y,VGP)
#
# /Users/ngothosk/Documents/MIT/simple-rl/robotworld.py in TrialRecurse(x, y, VGP)
#     140                 # print maxa, Q[maxa]
#     141                 (sx,sy),_ = self.transition(x,y,maxa)
# --> 142                 TrialRecurse(sx,sy,VGP)
#     143                 VGP, _,_ = self.GPFromDict(D)
#     144                 Q = self.q_estimate(x,y,VGP)
#
# /Users/ngothosk/Documents/MIT/simple-rl/robotworld.py in TrialRecurse(x, y, VGP)
#     140                 # print maxa, Q[maxa]
#     141                 (sx,sy),_ = self.transition(x,y,maxa)
# --> 142                 TrialRecurse(sx,sy,VGP)
#     143                 VGP, _,_ = self.GPFromDict(D)
#     144                 Q = self.q_estimate(x,y,VGP)
#
# /Users/ngothosk/Documents/MIT/simple-rl/robotworld.py in TrialRecurse(x, y, VGP)
#     140                 # print maxa, Q[maxa]
#     141                 (sx,sy),_ = self.transition(x,y,maxa)
# --> 142                 TrialRecurse(sx,sy,VGP)
#     143                 VGP, _,_ = self.GPFromDict(D)
#     144                 Q = self.q_estimate(x,y,VGP)
#
# /Users/ngothosk/Documents/MIT/simple-rl/robotworld.py in TrialRecurse(x, y, VGP)
#     140                 # print maxa, Q[maxa]
#     141                 (sx,sy),_ = self.transition(x,y,maxa)
# --> 142                 TrialRecurse(sx,sy,VGP)
#     143                 VGP, _,_ = self.GPFromDict(D)
#     144                 Q = self.q_estimate(x,y,VGP)
#
# /Users/ngothosk/Documents/MIT/simple-rl/robotworld.py in TrialRecurse(x, y, VGP)
#     140                 # print maxa, Q[maxa]
#     141                 (sx,sy),_ = self.transition(x,y,maxa)
# --> 142                 TrialRecurse(sx,sy,VGP)
#     143                 VGP, _,_ = self.GPFromDict(D)
#     144                 Q = self.q_estimate(x,y,VGP)
#
# /Users/ngothosk/Documents/MIT/simple-rl/robotworld.py in TrialRecurse(x, y, VGP)
#     140                 # print maxa, Q[maxa]
#     141                 (sx,sy),_ = self.transition(x,y,maxa)
# --> 142                 TrialRecurse(sx,sy,VGP)
#     143                 VGP, _,_ = self.GPFromDict(D)
#     144                 Q = self.q_estimate(x,y,VGP)
#
# /Users/ngothosk/Documents/MIT/simple-rl/robotworld.py in TrialRecurse(x, y, VGP)
#     140                 # print maxa, Q[maxa]
#     141                 (sx,sy),_ = self.transition(x,y,maxa)
# --> 142                 TrialRecurse(sx,sy,VGP)
#     143                 VGP, _,_ = self.GPFromDict(D)
#     144                 Q = self.q_estimate(x,y,VGP)
#
# /Users/ngothosk/Documents/MIT/simple-rl/robotworld.py in TrialRecurse(x, y, VGP)
#     140                 # print maxa, Q[maxa]
#     141                 (sx,sy),_ = self.transition(x,y,maxa)
# --> 142                 TrialRecurse(sx,sy,VGP)
#     143                 VGP, _,_ = self.GPFromDict(D)
#     144                 Q = self.q_estimate(x,y,VGP)
#
# /Users/ngothosk/Documents/MIT/simple-rl/robotworld.py in TrialRecurse(x, y, VGP)
#     140                 # print maxa, Q[maxa]
#     141                 (sx,sy),_ = self.transition(x,y,maxa)
# --> 142                 TrialRecurse(sx,sy,VGP)
#     143                 VGP, _,_ = self.GPFromDict(D)
#     144                 Q = self.q_estimate(x,y,VGP)
#
# /Users/ngothosk/Documents/MIT/simple-rl/robotworld.py in TrialRecurse(x, y, VGP)
#     140                 # print maxa, Q[maxa]
#     141                 (sx,sy),_ = self.transition(x,y,maxa)
# --> 142                 TrialRecurse(sx,sy,VGP)
#     143                 VGP, _,_ = self.GPFromDict(D)
#     144                 Q = self.q_estimate(x,y,VGP)
#
# /Users/ngothosk/Documents/MIT/simple-rl/robotworld.py in TrialRecurse(x, y, VGP)
#     140                 # print maxa, Q[maxa]
#     141                 (sx,sy),_ = self.transition(x,y,maxa)
# --> 142                 TrialRecurse(sx,sy,VGP)
#     143                 VGP, _,_ = self.GPFromDict(D)
#     144                 Q = self.q_estimate(x,y,VGP)
#
# /Users/ngothosk/Documents/MIT/simple-rl/robotworld.py in TrialRecurse(x, y, VGP)
#     140                 # print maxa, Q[maxa]
#     141                 (sx,sy),_ = self.transition(x,y,maxa)
# --> 142                 TrialRecurse(sx,sy,VGP)
#     143                 VGP, _,_ = self.GPFromDict(D)
#     144                 Q = self.q_estimate(x,y,VGP)
#
# /Users/ngothosk/Documents/MIT/simple-rl/robotworld.py in TrialRecurse(x, y, VGP)
#     140                 # print maxa, Q[maxa]
#     141                 (sx,sy),_ = self.transition(x,y,maxa)
# --> 142                 TrialRecurse(sx,sy,VGP)
#     143                 VGP, _,_ = self.GPFromDict(D)
#     144                 Q = self.q_estimate(x,y,VGP)
#
# /Users/ngothosk/Documents/MIT/simple-rl/robotworld.py in TrialRecurse(x, y, VGP)
#     140                 # print maxa, Q[maxa]
#     141                 (sx,sy),_ = self.transition(x,y,maxa)
# --> 142                 TrialRecurse(sx,sy,VGP)
#     143                 VGP, _,_ = self.GPFromDict(D)
#     144                 Q = self.q_estimate(x,y,VGP)
#
# /Users/ngothosk/Documents/MIT/simple-rl/robotworld.py in TrialRecurse(x, y, VGP)
#     140                 # print maxa, Q[maxa]
#     141                 (sx,sy),_ = self.transition(x,y,maxa)
# --> 142                 TrialRecurse(sx,sy,VGP)
#     143                 VGP, _,_ = self.GPFromDict(D)
#     144                 Q = self.q_estimate(x,y,VGP)
#
# /Users/ngothosk/Documents/MIT/simple-rl/robotworld.py in TrialRecurse(x, y, VGP)
#     140                 # print maxa, Q[maxa]
#     141                 (sx,sy),_ = self.transition(x,y,maxa)
# --> 142                 TrialRecurse(sx,sy,VGP)
#     143                 VGP, _,_ = self.GPFromDict(D)
#     144                 Q = self.q_estimate(x,y,VGP)
#
# /Users/ngothosk/Documents/MIT/simple-rl/robotworld.py in TrialRecurse(x, y, VGP)
#     140                 # print maxa, Q[maxa]
#     141                 (sx,sy),_ = self.transition(x,y,maxa)
# --> 142                 TrialRecurse(sx,sy,VGP)
#     143                 VGP, _,_ = self.GPFromDict(D)
#     144                 Q = self.q_estimate(x,y,VGP)
#
# /Users/ngothosk/Documents/MIT/simple-rl/robotworld.py in TrialRecurse(x, y, VGP)
#     140                 # print maxa, Q[maxa]
#     141                 (sx,sy),_ = self.transition(x,y,maxa)
# --> 142                 TrialRecurse(sx,sy,VGP)
#     143                 VGP, _,_ = self.GPFromDict(D)
#     144                 Q = self.q_estimate(x,y,VGP)
#
# /Users/ngothosk/Documents/MIT/simple-rl/robotworld.py in TrialRecurse(x, y, VGP)
#     140                 # print maxa, Q[maxa]
#     141                 (sx,sy),_ = self.transition(x,y,maxa)
# --> 142                 TrialRecurse(sx,sy,VGP)
#     143                 VGP, _,_ = self.GPFromDict(D)
#     144                 Q = self.q_estimate(x,y,VGP)
#
# /Users/ngothosk/Documents/MIT/simple-rl/robotworld.py in TrialRecurse(x, y, VGP)
#     140                 # print maxa, Q[maxa]
#     141                 (sx,sy),_ = self.transition(x,y,maxa)
# --> 142                 TrialRecurse(sx,sy,VGP)
#     143                 VGP, _,_ = self.GPFromDict(D)
#     144                 Q = self.q_estimate(x,y,VGP)
#
# /Users/ngothosk/Documents/MIT/simple-rl/robotworld.py in TrialRecurse(x, y, VGP)
#     140                 # print maxa, Q[maxa]
#     141                 (sx,sy),_ = self.transition(x,y,maxa)
# --> 142                 TrialRecurse(sx,sy,VGP)
#     143                 VGP, _,_ = self.GPFromDict(D)
#     144                 Q = self.q_estimate(x,y,VGP)
#
# /Users/ngothosk/Documents/MIT/simple-rl/robotworld.py in TrialRecurse(x, y, VGP)
#     142                 TrialRecurse(sx,sy,VGP)
#     143                 VGP, _,_ = self.GPFromDict(D)
# --> 144                 Q = self.q_estimate(x,y,VGP)
#     145                 maxa = max(Q, key=Q.get)
#     146                 print maxa, (x,y), Q[maxa]
#
# /Users/ngothosk/Documents/MIT/simple-rl/robotworld.py in q_estimate(self, x, y, V_prev)
#      75             result,_ = self.transition(x,y,a)
#      76             resultState= np.array([result])
# ---> 77             val =  (0.9*V_prev.predict(resultState)[0][0][0]) + self.reward(*result)
#      78             Q[a] = val
#      79         return Q
#
# /Users/ngothosk/Documents/MIT/simple-rl/robotworld.py in reward(self, nx, ny)
#      52         if self.in_goal(nx,ny):
#      53             return 10000.0
# ---> 54         distToEdge, _, _ = self.dist_to_poly(nx,ny,[self.bounds])
#      55         if distToEdge <1.0:
#      56             return (1.0 - distToEdge) * -1000.0
#
# /Users/ngothosk/Documents/MIT/simple-rl/robotworld.py in dist_to_poly(self, x, y, l)
#      37         dist = {}
#      38         for (i,obs) in enumerate(l):
# ---> 39             dist[i] = obs.boundary.distance(Point(x,y))
#      40         return dist,l[i],i
#      41
#
# /Users/ngothosk/Library/Python/2.7/lib/python/site-packages/shapely/geometry/base.pyc in boundary(self)
#     456         collection.
#     457         """
# --> 458         return geom_factory(self.impl['boundary'](self))
#     459
#     460     @property
#
# /Users/ngothosk/Library/Python/2.7/lib/python/site-packages/shapely/topology.pyc in __call__(self, this, *args)
#      75
#      76     def __call__(self, this, *args):
# ---> 77         self._validate(this)
#      78         return self.fn(this._geom, *args)
#
# /Users/ngothosk/Library/Python/2.7/lib/python/site-packages/shapely/topology.pyc in _validate(self, ob, stop_prepared)
#      15
#      16     def _validate(self, ob, stop_prepared=False):
# ---> 17         if ob is None or ob._geom is None:
#      18             raise ValueError("Null geometry supports no operations")
#      19         if stop_prepared and not hasattr(ob, 'type'):
#
# /Users/ngothosk/Library/Python/2.7/lib/python/site-packages/shapely/geometry/base.pyc in _geom(self)
#     251             self._ndim = 2
#     252
# --> 253     @property
#     254     def _geom(self):
#     255         return self.__geom__
#
# KeyboardInterrupt:

# %%
import matplotlib.pyplot as plt
import matplotlib.colors as colors

rx = [0,30]
ry = [0,30]
a = np.full((rx[1]-rx[0],ry[1]-ry[0]),0.0)
for i in range(rx[0],rx[1]):
    for j in range(ry[0],ry[1]):
        a[i-rx[0],j-ry[0]] = p.VPGS[-1].predict(np.array([[i,j]]))[0][0][0]
if a.min()< 0:
    a += -(a.min())
a+=.001
plt.imshow(a, cmap='hot',  norm=colors.LogNorm(vmin=a.min(), vmax=a.max()), interpolation='nearest')
# l =  p.VPGS[-1][1].keys()
# pl.plot([i[0] for i in l], [i[1] for i in l], 'ro')
plt.show()

# %%
print p.VPGS[-1].predict(np.array([[30.0, 30.0]]))
# Out:
# (array([[nan]]), array([[nan]]))

# %%
path = p.testValueFunction(p.VPGS[-1],30.0,30.0,60)
# Out:
# 30.0 30.0
# 29.279032054 29.3070315875
# 28.5580641079 28.6140631749
# 27.8370961619 27.9210947624
# 27.1161282159 27.2281263498
# 26.3951602698 26.5351579373
# 25.7117687058 25.8051059047
# 24.7398629119 25.5697357118
# 23.7568898122 25.7534852296
# 22.7572382703 25.7798821014
# 21.7575867284 25.7534852296
# 20.7607213947 25.6743681871
# 19.8381097428 25.2886380487
# 19.1941992956 24.5235371821
# 18.8701569973 23.5774945885
# 18.7516365221 22.5845429799
# 18.477973532 21.6227173367
# 17.8753388956 20.8247001095
# 17.2314284485 20.0595992429
# 16.5875180013 19.2944983763
# 15.9436075542 18.5293975097
# 15.2602159902 17.7993454772
# 14.616305543 17.0342446106
# 14.0566263682 16.2055352398
# 13.5414625813 15.348443487
# 13.0262987943 14.4913517343
# 12.3429072303 13.7612997017
# 11.4660923082 13.2804716738
# 10.9064131335 12.4517623029
# 10.7878926583 11.4588106943
# 10.7746930725 10.4588978127
# 10.7614934867 9.458984931
# 10.7482939009 8.45907204933
# 10.735094315 7.45915916766
# 10.7746838735 6.45994314153
# 10.5521629395 5.48501522935
# 9.99248376473 4.65630585851
# 9.11566884269 4.17547783054
# 8.12436815959 4.04386113071
# 7.12750282586 3.96474408822
# 6.13063749213 3.88562704572
# 5.13933680903 3.75401034589
# REACHED IN 41
# 4.19765385721 3.41750890717
# 3.2559709054 3.08100746845
# 2.27299780572 2.89725795063
# 3.26047879289 3.05499602457
# 2.26361345916 2.97587898208
# 3.26221986948 3.02865432921
# 2.26256832761 3.05505120098
# 3.26117473794 3.00227585385
# 2.26430940421 3.08139289634
# 3.25873892968 2.97598929644
# 2.27576583 3.15973881425
# 3.25354599225 2.95010591058
# 2.29541637984 3.23644075971
# 3.2456537799 2.92491406177
# 2.30397082809 3.2614155005
# 3.25420822815 2.94988880256
# 2.29607861574 3.23622365168
# 3.2463160158 2.92469695375

# %%
p.VPGS[-2].plot()

# %%
import numpy as np
import pylab as pl
from matplotlib import collections  as mc
import matplotlib.patches as patches
lines = []
for i in xrange(len(path)-1):
    lines.append([path[i],path[i+1]])

obstacles = []
for obs in p.obstacles:
    rec = patches.Rectangle((obs.bounds[0],obs.bounds[1]),obs.bounds[2]-obs.bounds[0],obs.bounds[3]-obs.bounds[1],linewidth=1,edgecolor='r',facecolor='none')
    obstacles.append(rec)


lc = mc.LineCollection(lines,linewidths=2)
fig, ax = pl.subplots()
# pl.plot([i[0] for i in path], [i[1] for i in path], 'ro')
for rec in obstacles:
    ax.add_patch(rec)

ax.add_collection(lc)
ax.autoscale()
ax.invert_yaxis()
ax.margins(0.1)

# %%
p.computeDeterministicTransition(30.0,30.0,3.9554314190044186)
# Out:
# (29.3132870090344, 29.27307134597742)

# %%
a = p.obstacles[0]

# %%
a.bounds
# Out:
# (5.0, 5.0, 10.0, 10.0)

# %%
integrate(p.VPGS[-1],4.0, 4.0,0.1)
# Out:
# (916.4493590139703, array([[0.71339208]]))

# %%
p.obstacles[0].boundary.distance(Point(0.0,0.0))
# Out:
# 7.0710678118654755

# %%
list(p.obstacles[0].boundary.coords)
# Out:
# [(15.0, 5.0), (15.0, 15.0), (5.0, 15.0), (5.0, 5.0), (15.0, 5.0)]

# %%
p.obstacles[0].boundary.distance(Point(10.0,10.0))
# Out:
# 5.0

# %%
# Out:
# (961, 1)
