# %%
run "gp_rtdp_bq.py"
# Out:
# ITERATION 0
# (30.0, 30.0)
# 3.8520030526427615
# (29.149566764599292, 29.305881192760527)
# 3.8835768481562267
# (28.669799096916897, 28.976777572837747)
# 3.5994126885350393
# (27.846165131508076, 28.51151781271644)
# 3.7572816661023656
# (26.89924076889827, 28.056822530712555)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/nishad/Documents/simple-RL/gp_rtdp_bq.py in <module>()
#     242
#     243 p = PWorld()
# --> 244 valueFunc = p.RTDP()
#     245
#     246 # print "play"
#
# /home/nishad/Documents/simple-RL/gp_rtdp_bq.py in RTDP(self)
#     150         for i in range(self.ITERS):
#     151             print "ITERATION %d" % (i)
# --> 152             D_temp = TrialRecurseWrapper(30.0,30.0,i,VGP)
#     153             self.Dicts.append(D_temp)
#     154             VGP, _,_ = self.GPFromDict(self.mergeLastN(self.Dicts,10))
#
# /home/nishad/Documents/simple-RL/gp_rtdp_bq.py in TrialRecurseWrapper(ax, ay, iteration, VGP)
#     145                 D_temp[(x,y)] = Q[maxa]
#     146
# --> 147             TrialRecurse(ax,ay,VGP)
#     148             return D_temp
#     149
#
# /home/nishad/Documents/simple-RL/gp_rtdp_bq.py in TrialRecurse(x, y, VGP)
#     138                 print maxa
#     139                 (sx,sy) = self.computeResult(x,y,maxa)
# --> 140                 TrialRecurse(sx,sy,VGP)
#     141                 VGP, _,_ = self.GPFromDict(self.mergeLastN(self.Dicts+[D_temp],10))
#     142                 Q = self.Qestimate(x,y,VGP)
#
# /home/nishad/Documents/simple-RL/gp_rtdp_bq.py in TrialRecurse(x, y, VGP)
#     138                 print maxa
#     139                 (sx,sy) = self.computeResult(x,y,maxa)
# --> 140                 TrialRecurse(sx,sy,VGP)
#     141                 VGP, _,_ = self.GPFromDict(self.mergeLastN(self.Dicts+[D_temp],10))
#     142                 Q = self.Qestimate(x,y,VGP)
#
# /home/nishad/Documents/simple-RL/gp_rtdp_bq.py in TrialRecurse(x, y, VGP)
#     138                 print maxa
#     139                 (sx,sy) = self.computeResult(x,y,maxa)
# --> 140                 TrialRecurse(sx,sy,VGP)
#     141                 VGP, _,_ = self.GPFromDict(self.mergeLastN(self.Dicts+[D_temp],10))
#     142                 Q = self.Qestimate(x,y,VGP)
#
# /home/nishad/Documents/simple-RL/gp_rtdp_bq.py in TrialRecurse(x, y, VGP)
#     138                 print maxa
#     139                 (sx,sy) = self.computeResult(x,y,maxa)
# --> 140                 TrialRecurse(sx,sy,VGP)
#     141                 VGP, _,_ = self.GPFromDict(self.mergeLastN(self.Dicts+[D_temp],10))
#     142                 Q = self.Qestimate(x,y,VGP)
#
# /home/nishad/Documents/simple-RL/gp_rtdp_bq.py in TrialRecurse(x, y, VGP)
#     134                 if self.inGoal(x,y):
#     135                     return
# --> 136                 Q = self.Qestimate(x,y,VGP)
#     137                 maxa = max(Q, key=Q.get)
#     138                 print maxa
#
# /home/nishad/Documents/simple-RL/gp_rtdp_bq.py in Qestimate(self, x, y, V_prev)
#      82             tot = 0
#      83             for i in range(self.ATTEMPTS):
# ---> 84                 result = self.computeResult(x,y,a)
#      85                 resultState= np.array([result])
#      86                 tot +=  (0.95*V_prev.predict(resultState)[0][0][0] if not self.inGoal(*result) else 0) + self.rewardFunction(*result)
#
# /home/nishad/Documents/simple-RL/gp_rtdp_bq.py in computeResult(self, x, y, angle)
#      41     def computeResult(self,x,y,angle):
#      42         newX, newY = self.computeUnsquashedResult(x,y,angle)
# ---> 43         if not self.inWorld(newX,newY):
#      44             return x,y
#      45         return self.squash(newX,newY)
#
# /home/nishad/Documents/simple-RL/gp_rtdp_bq.py in inWorld(self, x, y)
#      26
#      27     def inWorld(self,x,y):
# ---> 28         if self.inObstacle(x,y):
#      29             return False
#      30         return x < self.maxX and y < self.maxY  and x >= self.minX and y >= self.minY
#
# /home/nishad/Documents/simple-RL/gp_rtdp_bq.py in inObstacle(self, x, y)
#      21     def inObstacle(self,x,y):
#      22         for [x1,x2,y1,y2] in self.obstacles:
# ---> 23             if x>=x1 and x<=x2 and y>=y1 and y<=y2:
#      24                 return True
#      25         return False
#
# KeyboardInterrupt:

# %%
import matplotlib.pyplot as plt
import matplotlib.colors as colors

rx = [0,30]
ry = [0,30]
a = np.full((rx[1]-rx[0],ry[1]-ry[0]),0.0)
for i in range(rx[0],rx[1]):
    for j in range(ry[0],ry[1]):
        a[i-rx[0],j-ry[0]] = p.VPGS[-1].predict(np.array([[i,j]]))[0][0][0]
if a.min()< 0:
    a += -(a.min())
a+=.001
plt.imshow(a, cmap='hot',  norm=colors.LogNorm(vmin=a.min(), vmax=a.max()), interpolation='nearest')
# l =  p.VPGS[-1][1].keys()
# pl.plot([i[0] for i in l], [i[1] for i in l], 'ro')
plt.show()

# %%
print p.VPGS[-1].predict(np.array([[27.787532616677595, 27.738565118287685]]))
# print p.Dicts
# print p.VPGS[-1]
# Out:
# (array([[1194.00185372]]), array([[1.31805655]]))

# %%
path = p.testValueFunction(p.VPGS[-2],30.0,30.0,100)
# Out:
# 44

# %%
p.VPGS[-1].plot()

# %%
import numpy as np
import pylab as pl
from matplotlib import collections  as mc
import matplotlib.patches as patches
lines = []
for i in xrange(len(path)-20):
    lines.append([path[i],path[i+1]])

obstacles = []
for obs in p.obstacles:
    rec = patches.Rectangle((obs[0],obs[2]),obs[1]-obs[0],obs[3]-obs[2],linewidth=1,edgecolor='r',facecolor='none')
    obstacles.append(rec)


lc = mc.LineCollection(lines,linewidths=2)
fig, ax = pl.subplots()
# pl.plot([i[0] for i in path], [i[1] for i in path], 'ro')
for rec in obstacles:
    ax.add_patch(rec)

ax.add_collection(lc)
ax.autoscale()
ax.invert_yaxis()
ax.margins(0.1)

# %%
p.computeDeterministicTransition(30.0,30.0,3.9554314190044186)
# Out:
# (29.3132870090344, 29.27307134597742)

# %%
np.random.multivariate_normal([0,0], [[0.1,0],[0,0.1]])
# Out:
# array([0.17700912, 0.37683361])

# %%
t = p.VPGS[-1]

# %%
integrate(t,27.787532616677595, 27.738565118287685,0.05)
# Out:
# (1522.139601769424, array([[0.00114164]]))
