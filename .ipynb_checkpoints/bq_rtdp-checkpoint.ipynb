# 3.3002589492256416
# (80.8864467393384, 83.5842446289035)
# 3.8079910952603555
# (80.41864127804236, 82.40043794065693)
# 3.236792430971302
# (79.45980785432427, 81.74579692333786)
# 2.982926357953945
# (78.5173987140015, 81.74229753328113)
# 3.3637254674799806
# (77.23498855156507, 81.534294239269)
# 3.744524577006016
# (76.45203169196095, 81.13310964819492)
# 3.934924131769034
# (76.20769818021519, 80.49379565427672)
# 3.744524577006016
# (75.00240969776685, 79.87653810241515)
# 4.25225672304073
# (74.95106934842559, 78.95157683811081)
# 3.8079910952603555
# (74.2065677353134, 78.03633519768549)
# 3.934924131769034
# (73.1972335319709, 77.32769872832144)
# 4.506122796058087
# (73.06685714908892, 76.61000367321628)
# 4.3791897595494085
# (73.36247229851465, 75.90612478527567)
# 3.934924131769034
# (73.33108306498345, 75.15501233481102)
# 3.6175915404973376
# (72.983783860615, 74.66323529060618)
# 3.681058058751677
# (72.54316957631238, 74.34428524916399)
# 3.998390650023373
# (71.70158121463425, 73.18561231521649)
# 4.25225672304073
# (71.24912236119127, 72.32014687993744)
# 4.0618571682777125
# (69.91978307730867, 72.08424289319693)
# 4.1253236865320515
# (69.67172136558689, 71.28477789417262)
# 3.490658503988659
# (68.90209121222676, 70.73623360943496)
# 3.3637254674799806
# (68.0253190096268, 69.5887877684701)
# 3.6175915404973376
# (67.3792688608719, 68.79923241466985)
# 3.744524577006016
# (66.82486866439662, 68.41262172660161)
# 3.998390650023373
# (66.04636326499023, 68.07522736607869)
# 4.3791897595494085
# (65.92368271055608, 67.31929415753804)
# 3.998390650023373
# (65.20613422765715, 66.9429623287142)
# 4.188790204786391
# (65.05681056348001, 66.56971359264753)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/nishad/Documents/simple-RL/gp_rtdp_bq.py in <module>()
#     292
#     293 p = PWorld()
# --> 294 valueFunc = p.RTDP()
#     295 # valueFunc = p.valueiteration()
#     296
#
# /home/nishad/Documents/simple-RL/gp_rtdp_bq.py in RTDP(self)
#     161         for i in range(self.ITERS):
#     162             print "ITERATION %d" % (i)
# --> 163             D_temp = TrialRecurseWrapper(100.0,100.0,i,VGP)
#     164             self.Dicts.append(D_temp)
#     165             VGP, _,_ = self.GPFromDict(self.mergeLastN(self.Dicts,1))
#
# /home/nishad/Documents/simple-RL/gp_rtdp_bq.py in TrialRecurseWrapper(ax, ay, iteration, VGP)
# ...
#
# /home/nishad/Documents/simple-RL/gp_rtdp_bq.py in TrialRecurse(x, y, VGP)
#     149                 print maxa
#     150                 (sx,sy) = self.computeResult(x,y,maxa)
# --> 151                 TrialRecurse(sx,sy,VGP)
#     152                 VGP, _,_ = self.GPFromDict(self.mergeLastN(self.Dicts+[D_temp],1))
#     153                 Q = self.Qestimate(x,y,VGP)
#
# /home/nishad/Documents/simple-RL/gp_rtdp_bq.py in TrialRecurse(x, y, VGP)
#     149                 print maxa
#     150                 (sx,sy) = self.computeResult(x,y,maxa)
# --> 151                 TrialRecurse(sx,sy,VGP)
#     152                 VGP, _,_ = self.GPFromDict(self.mergeLastN(self.Dicts+[D_temp],1))
#     153                 Q = self.Qestimate(x,y,VGP)
#
# /home/nishad/Documents/simple-RL/gp_rtdp_bq.py in TrialRecurse(x, y, VGP)
#     149                 print maxa
#     150                 (sx,sy) = self.computeResult(x,y,maxa)
# --> 151                 TrialRecurse(sx,sy,VGP)
#     152                 VGP, _,_ = self.GPFromDict(self.mergeLastN(self.Dicts+[D_temp],1))
#     153                 Q = self.Qestimate(x,y,VGP)
#
# /home/nishad/Documents/simple-RL/gp_rtdp_bq.py in TrialRecurse(x, y, VGP)
#     149                 print maxa
#     150                 (sx,sy) = self.computeResult(x,y,maxa)
# --> 151                 TrialRecurse(sx,sy,VGP)
#     152                 VGP, _,_ = self.GPFromDict(self.mergeLastN(self.Dicts+[D_temp],1))
#     153                 Q = self.Qestimate(x,y,VGP)
#
# /home/nishad/Documents/simple-RL/gp_rtdp_bq.py in TrialRecurse(x, y, VGP)
#     149                 print maxa
#     150                 (sx,sy) = self.computeResult(x,y,maxa)
# --> 151                 TrialRecurse(sx,sy,VGP)
#     152                 VGP, _,_ = self.GPFromDict(self.mergeLastN(self.Dicts+[D_temp],1))
#     153                 Q = self.Qestimate(x,y,VGP)
#
# /home/nishad/Documents/simple-RL/gp_rtdp_bq.py in TrialRecurse(x, y, VGP)
#     149                 print maxa
#     150                 (sx,sy) = self.computeResult(x,y,maxa)
# --> 151                 TrialRecurse(sx,sy,VGP)
#     152                 VGP, _,_ = self.GPFromDict(self.mergeLastN(self.Dicts+[D_temp],1))
#     153                 Q = self.Qestimate(x,y,VGP)
#
# /home/nishad/Documents/simple-RL/gp_rtdp_bq.py in TrialRecurse(x, y, VGP)
#     149                 print maxa
#     150                 (sx,sy) = self.computeResult(x,y,maxa)
# --> 151                 TrialRecurse(sx,sy,VGP)
#     152                 VGP, _,_ = self.GPFromDict(self.mergeLastN(self.Dicts+[D_temp],1))
#     153                 Q = self.Qestimate(x,y,VGP)
#
# /home/nishad/Documents/simple-RL/gp_rtdp_bq.py in TrialRecurse(x, y, VGP)
#     149                 print maxa
#     150                 (sx,sy) = self.computeResult(x,y,maxa)
# --> 151                 TrialRecurse(sx,sy,VGP)
#     152                 VGP, _,_ = self.GPFromDict(self.mergeLastN(self.Dicts+[D_temp],1))
#     153                 Q = self.Qestimate(x,y,VGP)
#
# /home/nishad/Documents/simple-RL/gp_rtdp_bq.py in TrialRecurse(x, y, VGP)
#     149                 print maxa
#     150                 (sx,sy) = self.computeResult(x,y,maxa)
# --> 151                 TrialRecurse(sx,sy,VGP)
#     152                 VGP, _,_ = self.GPFromDict(self.mergeLastN(self.Dicts+[D_temp],1))
#     153                 Q = self.Qestimate(x,y,VGP)
#
# /home/nishad/Documents/simple-RL/gp_rtdp_bq.py in TrialRecurse(x, y, VGP)
#     149                 print maxa
#     150                 (sx,sy) = self.computeResult(x,y,maxa)
# --> 151                 TrialRecurse(sx,sy,VGP)
#     152                 VGP, _,_ = self.GPFromDict(self.mergeLastN(self.Dicts+[D_temp],1))
#     153                 Q = self.Qestimate(x,y,VGP)
#
# /home/nishad/Documents/simple-RL/gp_rtdp_bq.py in TrialRecurse(x, y, VGP)
#     149                 print maxa
#     150                 (sx,sy) = self.computeResult(x,y,maxa)
# --> 151                 TrialRecurse(sx,sy,VGP)
#     152                 VGP, _,_ = self.GPFromDict(self.mergeLastN(self.Dicts+[D_temp],1))
#     153                 Q = self.Qestimate(x,y,VGP)
#
# /home/nishad/Documents/simple-RL/gp_rtdp_bq.py in TrialRecurse(x, y, VGP)
#     149                 print maxa
#     150                 (sx,sy) = self.computeResult(x,y,maxa)
# --> 151                 TrialRecurse(sx,sy,VGP)
#     152                 VGP, _,_ = self.GPFromDict(self.mergeLastN(self.Dicts+[D_temp],1))
#     153                 Q = self.Qestimate(x,y,VGP)
#
# /home/nishad/Documents/simple-RL/gp_rtdp_bq.py in TrialRecurse(x, y, VGP)
#     149                 print maxa
#     150                 (sx,sy) = self.computeResult(x,y,maxa)
# --> 151                 TrialRecurse(sx,sy,VGP)
#     152                 VGP, _,_ = self.GPFromDict(self.mergeLastN(self.Dicts+[D_temp],1))
#     153                 Q = self.Qestimate(x,y,VGP)
#
# /home/nishad/Documents/simple-RL/gp_rtdp_bq.py in TrialRecurse(x, y, VGP)
#     149                 print maxa
#     150                 (sx,sy) = self.computeResult(x,y,maxa)
# --> 151                 TrialRecurse(sx,sy,VGP)
#     152                 VGP, _,_ = self.GPFromDict(self.mergeLastN(self.Dicts+[D_temp],1))
#     153                 Q = self.Qestimate(x,y,VGP)
#
# /home/nishad/Documents/simple-RL/gp_rtdp_bq.py in TrialRecurse(x, y, VGP)
#     149                 print maxa
#     150                 (sx,sy) = self.computeResult(x,y,maxa)
# --> 151                 TrialRecurse(sx,sy,VGP)
#     152                 VGP, _,_ = self.GPFromDict(self.mergeLastN(self.Dicts+[D_temp],1))
#     153                 Q = self.Qestimate(x,y,VGP)
#
# /home/nishad/Documents/simple-RL/gp_rtdp_bq.py in TrialRecurse(x, y, VGP)
#     149                 print maxa
#     150                 (sx,sy) = self.computeResult(x,y,maxa)
# --> 151                 TrialRecurse(sx,sy,VGP)
#     152                 VGP, _,_ = self.GPFromDict(self.mergeLastN(self.Dicts+[D_temp],1))
#     153                 Q = self.Qestimate(x,y,VGP)
#
# /home/nishad/Documents/simple-RL/gp_rtdp_bq.py in TrialRecurse(x, y, VGP)
#     149                 print maxa
#     150                 (sx,sy) = self.computeResult(x,y,maxa)
# --> 151                 TrialRecurse(sx,sy,VGP)
#     152                 VGP, _,_ = self.GPFromDict(self.mergeLastN(self.Dicts+[D_temp],1))
#     153                 Q = self.Qestimate(x,y,VGP)
#
# /home/nishad/Documents/simple-RL/gp_rtdp_bq.py in TrialRecurse(x, y, VGP)
#     149                 print maxa
#     150                 (sx,sy) = self.computeResult(x,y,maxa)
# --> 151                 TrialRecurse(sx,sy,VGP)
#     152                 VGP, _,_ = self.GPFromDict(self.mergeLastN(self.Dicts+[D_temp],1))
#     153                 Q = self.Qestimate(x,y,VGP)
#
# /home/nishad/Documents/simple-RL/gp_rtdp_bq.py in TrialRecurse(x, y, VGP)
#     149                 print maxa
#     150                 (sx,sy) = self.computeResult(x,y,maxa)
# --> 151                 TrialRecurse(sx,sy,VGP)
#     152                 VGP, _,_ = self.GPFromDict(self.mergeLastN(self.Dicts+[D_temp],1))
#     153                 Q = self.Qestimate(x,y,VGP)
#
# /home/nishad/Documents/simple-RL/gp_rtdp_bq.py in TrialRecurse(x, y, VGP)
#     149                 print maxa
#     150                 (sx,sy) = self.computeResult(x,y,maxa)
# --> 151                 TrialRecurse(sx,sy,VGP)
#     152                 VGP, _,_ = self.GPFromDict(self.mergeLastN(self.Dicts+[D_temp],1))
#     153                 Q = self.Qestimate(x,y,VGP)
#
# /home/nishad/Documents/simple-RL/gp_rtdp_bq.py in TrialRecurse(x, y, VGP)
#     149                 print maxa
#     150                 (sx,sy) = self.computeResult(x,y,maxa)
# --> 151                 TrialRecurse(sx,sy,VGP)
#     152                 VGP, _,_ = self.GPFromDict(self.mergeLastN(self.Dicts+[D_temp],1))
#     153                 Q = self.Qestimate(x,y,VGP)
#
# /home/nishad/Documents/simple-RL/gp_rtdp_bq.py in TrialRecurse(x, y, VGP)
#     149                 print maxa
#     150                 (sx,sy) = self.computeResult(x,y,maxa)
# --> 151                 TrialRecurse(sx,sy,VGP)
#     152                 VGP, _,_ = self.GPFromDict(self.mergeLastN(self.Dicts+[D_temp],1))
#     153                 Q = self.Qestimate(x,y,VGP)
#
# /home/nishad/Documents/simple-RL/gp_rtdp_bq.py in TrialRecurse(x, y, VGP)
#     149                 print maxa
#     150                 (sx,sy) = self.computeResult(x,y,maxa)
# --> 151                 TrialRecurse(sx,sy,VGP)
#     152                 VGP, _,_ = self.GPFromDict(self.mergeLastN(self.Dicts+[D_temp],1))
#     153                 Q = self.Qestimate(x,y,VGP)
#
# /home/nishad/Documents/simple-RL/gp_rtdp_bq.py in TrialRecurse(x, y, VGP)
#     149                 print maxa
#     150                 (sx,sy) = self.computeResult(x,y,maxa)
# --> 151                 TrialRecurse(sx,sy,VGP)
#     152                 VGP, _,_ = self.GPFromDict(self.mergeLastN(self.Dicts+[D_temp],1))
#     153                 Q = self.Qestimate(x,y,VGP)
#
# /home/nishad/Documents/simple-RL/gp_rtdp_bq.py in TrialRecurse(x, y, VGP)
#     149                 print maxa
#     150                 (sx,sy) = self.computeResult(x,y,maxa)
# --> 151                 TrialRecurse(sx,sy,VGP)
#     152                 VGP, _,_ = self.GPFromDict(self.mergeLastN(self.Dicts+[D_temp],1))
#     153                 Q = self.Qestimate(x,y,VGP)
#
# /home/nishad/Documents/simple-RL/gp_rtdp_bq.py in TrialRecurse(x, y, VGP)
#     149                 print maxa
#     150                 (sx,sy) = self.computeResult(x,y,maxa)
# --> 151                 TrialRecurse(sx,sy,VGP)
#     152                 VGP, _,_ = self.GPFromDict(self.mergeLastN(self.Dicts+[D_temp],1))
#     153                 Q = self.Qestimate(x,y,VGP)
#
# /home/nishad/Documents/simple-RL/gp_rtdp_bq.py in TrialRecurse(x, y, VGP)
#     149                 print maxa
#     150                 (sx,sy) = self.computeResult(x,y,maxa)
# --> 151                 TrialRecurse(sx,sy,VGP)
#     152                 VGP, _,_ = self.GPFromDict(self.mergeLastN(self.Dicts+[D_temp],1))
#     153                 Q = self.Qestimate(x,y,VGP)
#
# /home/nishad/Documents/simple-RL/gp_rtdp_bq.py in TrialRecurse(x, y, VGP)
#     149                 print maxa
#     150                 (sx,sy) = self.computeResult(x,y,maxa)
# --> 151                 TrialRecurse(sx,sy,VGP)
#     152                 VGP, _,_ = self.GPFromDict(self.mergeLastN(self.Dicts+[D_temp],1))
#     153                 Q = self.Qestimate(x,y,VGP)
#
# /home/nishad/Documents/simple-RL/gp_rtdp_bq.py in TrialRecurse(x, y, VGP)
#     149                 print maxa
#     150                 (sx,sy) = self.computeResult(x,y,maxa)
# --> 151                 TrialRecurse(sx,sy,VGP)
#     152                 VGP, _,_ = self.GPFromDict(self.mergeLastN(self.Dicts+[D_temp],1))
#     153                 Q = self.Qestimate(x,y,VGP)
#
# /home/nishad/Documents/simple-RL/gp_rtdp_bq.py in TrialRecurse(x, y, VGP)
#     149                 print maxa
#     150                 (sx,sy) = self.computeResult(x,y,maxa)
# --> 151                 TrialRecurse(sx,sy,VGP)
#     152                 VGP, _,_ = self.GPFromDict(self.mergeLastN(self.Dicts+[D_temp],1))
#     153                 Q = self.Qestimate(x,y,VGP)
#
# /home/nishad/Documents/simple-RL/gp_rtdp_bq.py in TrialRecurse(x, y, VGP)
#     149                 print maxa
#     150                 (sx,sy) = self.computeResult(x,y,maxa)
# --> 151                 TrialRecurse(sx,sy,VGP)
#     152                 VGP, _,_ = self.GPFromDict(self.mergeLastN(self.Dicts+[D_temp],1))
#     153                 Q = self.Qestimate(x,y,VGP)
#
# /home/nishad/Documents/simple-RL/gp_rtdp_bq.py in TrialRecurse(x, y, VGP)
#     149                 print maxa
#     150                 (sx,sy) = self.computeResult(x,y,maxa)
# --> 151                 TrialRecurse(sx,sy,VGP)
#     152                 VGP, _,_ = self.GPFromDict(self.mergeLastN(self.Dicts+[D_temp],1))
#     153                 Q = self.Qestimate(x,y,VGP)
#
# /home/nishad/Documents/simple-RL/gp_rtdp_bq.py in TrialRecurse(x, y, VGP)
#     149                 print maxa
#     150                 (sx,sy) = self.computeResult(x,y,maxa)
# --> 151                 TrialRecurse(sx,sy,VGP)
#     152                 VGP, _,_ = self.GPFromDict(self.mergeLastN(self.Dicts+[D_temp],1))
#     153                 Q = self.Qestimate(x,y,VGP)
#
# /home/nishad/Documents/simple-RL/gp_rtdp_bq.py in TrialRecurse(x, y, VGP)
#     149                 print maxa
#     150                 (sx,sy) = self.computeResult(x,y,maxa)
# --> 151                 TrialRecurse(sx,sy,VGP)
#     152                 VGP, _,_ = self.GPFromDict(self.mergeLastN(self.Dicts+[D_temp],1))
#     153                 Q = self.Qestimate(x,y,VGP)
#
# /home/nishad/Documents/simple-RL/gp_rtdp_bq.py in TrialRecurse(x, y, VGP)
#     149                 print maxa
#     150                 (sx,sy) = self.computeResult(x,y,maxa)
# --> 151                 TrialRecurse(sx,sy,VGP)
#     152                 VGP, _,_ = self.GPFromDict(self.mergeLastN(self.Dicts+[D_temp],1))
#     153                 Q = self.Qestimate(x,y,VGP)
#
# /home/nishad/Documents/simple-RL/gp_rtdp_bq.py in TrialRecurse(x, y, VGP)
#     149                 print maxa
#     150                 (sx,sy) = self.computeResult(x,y,maxa)
# --> 151                 TrialRecurse(sx,sy,VGP)
#     152                 VGP, _,_ = self.GPFromDict(self.mergeLastN(self.Dicts+[D_temp],1))
#     153                 Q = self.Qestimate(x,y,VGP)
#
# /home/nishad/Documents/simple-RL/gp_rtdp_bq.py in TrialRecurse(x, y, VGP)
#     149                 print maxa
#     150                 (sx,sy) = self.computeResult(x,y,maxa)
# --> 151                 TrialRecurse(sx,sy,VGP)
#     152                 VGP, _,_ = self.GPFromDict(self.mergeLastN(self.Dicts+[D_temp],1))
#     153                 Q = self.Qestimate(x,y,VGP)
#
# /home/nishad/Documents/simple-RL/gp_rtdp_bq.py in TrialRecurse(x, y, VGP)
#     149                 print maxa
#     150                 (sx,sy) = self.computeResult(x,y,maxa)
# --> 151                 TrialRecurse(sx,sy,VGP)
#     152                 VGP, _,_ = self.GPFromDict(self.mergeLastN(self.Dicts+[D_temp],1))
#     153                 Q = self.Qestimate(x,y,VGP)
#
# /home/nishad/Documents/simple-RL/gp_rtdp_bq.py in TrialRecurse(x, y, VGP)
#     149                 print maxa
#     150                 (sx,sy) = self.computeResult(x,y,maxa)
# --> 151                 TrialRecurse(sx,sy,VGP)
#     152                 VGP, _,_ = self.GPFromDict(self.mergeLastN(self.Dicts+[D_temp],1))
#     153                 Q = self.Qestimate(x,y,VGP)
#
# /home/nishad/Documents/simple-RL/gp_rtdp_bq.py in TrialRecurse(x, y, VGP)
#     149                 print maxa
#     150                 (sx,sy) = self.computeResult(x,y,maxa)
# --> 151                 TrialRecurse(sx,sy,VGP)
#     152                 VGP, _,_ = self.GPFromDict(self.mergeLastN(self.Dicts+[D_temp],1))
#     153                 Q = self.Qestimate(x,y,VGP)
#
# /home/nishad/Documents/simple-RL/gp_rtdp_bq.py in TrialRecurse(x, y, VGP)
#     149                 print maxa
#     150                 (sx,sy) = self.computeResult(x,y,maxa)
# --> 151                 TrialRecurse(sx,sy,VGP)
#     152                 VGP, _,_ = self.GPFromDict(self.mergeLastN(self.Dicts+[D_temp],1))
#     153                 Q = self.Qestimate(x,y,VGP)
#
# /home/nishad/Documents/simple-RL/gp_rtdp_bq.py in TrialRecurse(x, y, VGP)
#     145                 if self.inGoal(x,y):
#     146                     return
# --> 147                 Q = self.Qestimate(x,y,VGP)
#     148                 maxa = max(Q, key=Q.get)
#     149                 print maxa
#
# /home/nishad/Documents/simple-RL/gp_rtdp_bq.py in Qestimate(self, x, y, V_prev)
#      86             # Q[a] = tot/float(self.ATTEMPTS)
#      87             nx,ny = self.computeDeterministicTransition(x,y,a)
# ---> 88             Q[a] = 0.95*integrate(V_prev,nx,ny,0.1)[0]
#      89         return Q
#      90
#
# /home/nishad/Documents/simple-RL/gp_rtdp_bq.py in integrate(gp, ix, iy, v)
#     288         z[i,:] =computeZ(gp,X,i,A,B,b,I)
#     289
# --> 290     return (computeMean(z,Wi,Y),computeVariance(gp,z,Wi,A,B,I))
#     291
#     292
#
# /home/nishad/Documents/simple-RL/gp_rtdp_bq.py in computeMean(z, Wi, y)
#     252
#     253 def computeMean(z,Wi,y):
# --> 254     return np.dot(np.dot(z.T,Wi),y)[0][0]
#     255
#     256 def computeVariance(gp,z,Wi,A,B,I):
#
# KeyboardInterrupt:

# %%
import matplotlib.pyplot as plt
import matplotlib.colors as colors

rx = [0,30]
ry = [0,30]
a = np.full((rx[1]-rx[0],ry[1]-ry[0]),0.0)
for i in range(rx[0],rx[1]):
    for j in range(ry[0],ry[1]):
        a[i-rx[0],j-ry[0]] = p.VPGS[-1].predict(np.array([[i,j]]))[0][0][0]
if a.min()< 0:
    a += -(a.min())
a+=.001
plt.imshow(a, cmap='hot',  norm=colors.LogNorm(vmin=a.min(), vmax=a.max()), interpolation='nearest')
# l =  p.VPGS[-1][1].keys()
# pl.plot([i[0] for i in l], [i[1] for i in l], 'ro')
plt.show()

# %%
print p.VPGS[-1].predict(np.array([[25.787532616677595, 25.738565118287685]]))
# print p.Dicts
# print p.VPGS[-1]
# Out:
# (array([[0.00094677]]), array([[1.7801912]]))

# %%
path = p.testValueFunction(p.VPGS[-1],30.0,30.0,100)
# Out:
# 50

# %%
p.VPGS[-1].plot()

# %%
import numpy as np
import pylab as pl
from matplotlib import collections  as mc
import matplotlib.patches as patches
lines = []
for i in xrange(len(path)-20):
    lines.append([path[i],path[i+1]])

obstacles = []
for obs in p.obstacles:
    rec = patches.Rectangle((obs[0],obs[2]),obs[1]-obs[0],obs[3]-obs[2],linewidth=1,edgecolor='r',facecolor='none')
    obstacles.append(rec)


lc = mc.LineCollection(lines,linewidths=2)
fig, ax = pl.subplots()
# pl.plot([i[0] for i in path], [i[1] for i in path], 'ro')
for rec in obstacles:
    ax.add_patch(rec)

ax.add_collection(lc)
ax.autoscale()
ax.invert_yaxis()
ax.margins(0.1)

# %%
p.computeDeterministicTransition(30.0,30.0,3.9554314190044186)
# Out:
# (29.3132870090344, 29.27307134597742)

# %%
np.random.multivariate_normal([0,0], [[0.1,0],[0,0.1]])
# Out:
# array([-0.19904836, -0.54020587])

# %%
len(p.VPGS)
# Out:
# 7

# %%
integrate(p.VPGS[-1],4.0, 4.0,0.1)
# Out:
# (916.4493590139703, array([[0.71339208]]))

# %%
p.VPGS[-1]
# Out:
# <style type="text/css">
# .pd{
#     font-family: "Courier New", Courier, monospace !important;
#     width: 100%;
#     padding: 3px;
# }
# </style>
#
# <p class=pd>
# <b>Model</b>: GP regression<br>
# <b>Objective</b>: 47028287.2152<br>
# <b>Number of Parameters</b>: 3<br>
# <b>Number of Optimization Parameters</b>: 3<br>
# <b>Updates</b>: True<br>
# </p>
# <style type="text/css">
# .tg  {font-family:"Courier New", Courier, monospace !important;padding:2px 3px;word-break:normal;border-collapse:collapse;border-spacing:0;border-color:#DCDCDC;margin:0px auto;width:100%;}
# .tg td{font-family:"Courier New", Courier, monospace !important;font-weight:bold;color:#444;background-color:#F7FDFA;border-style:solid;border-width:1px;overflow:hidden;word-break:normal;border-color:#DCDCDC;}
# .tg th{font-family:"Courier New", Courier, monospace !important;font-weight:normal;color:#fff;background-color:#26ADE4;border-style:solid;border-width:1px;overflow:hidden;word-break:normal;border-color:#DCDCDC;}
# .tg .tg-left{font-family:"Courier New", Courier, monospace !important;font-weight:normal;text-align:left;}
# .tg .tg-center{font-family:"Courier New", Courier, monospace !important;font-weight:normal;text-align:center;}
# .tg .tg-right{font-family:"Courier New", Courier, monospace !important;font-weight:normal;text-align:right;}
# </style>
# <table class="tg"><tr><th><b>  GP_regression.         </b></th><th><b>value</b></th><th><b>constraints</b></th><th><b>priors</b></th></tr>
# <tr><td class=tg-left>  rbf.variance           </td><td class=tg-right>  1.0</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  rbf.lengthscale        </td><td class=tg-right>  1.0</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  Gaussian_noise.variance</td><td class=tg-right>  1.0</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# </table>

# %%
list(S)
# Out:
# [(29.374787125920164, 27.487191691598817),
#  (10.21166605453272, 26.034821166841855),
#  (16.04146345921223, 8.618630960760035),
#  (19.19757773266394, 24.18543686958022),
#  (3.3973183856919427, 25.76650003582959),
#  (24.968304351208715, 28.065947313424424),
#  (12.833603599747036, 16.604799139626714),
#  (20.2347393978028, 25.86511394238528),
#  (26.284110251003348, 25.23219839283899),
#  (10.443120710579139, 5.143209127806822),
#  (4.010853460991387, 26.55616750469057),
#  (20.425860596457333, 16.233954925911423),
#  (20.384374907093473, 17.233094024124483),
#  (15.106999373405891, 16.57052179693075),
#  (15.021744639724346, 3.193723056283892),
#  (11.202654565144792, 5.793676900850684),
#  (16.1764844895047, 17.647211740265192),
#  (22.980627671055096, 3.079736932243486),
#  (2.732406824063042, 0.8824943795495401),
#  (11.088135633149522, 21.61738594610719),
#  (10.284492886504733, 9.972168275340497),
#  (13.045231111743197, 8.380223738993083),
#  (19.002127408365176, 21.5261870521238),
#  (16.821486616927842, 16.997373981517907),
#  (29.347476805546236, 28.48681869523621),
#  (21.03146644488296, 15.438190163966865),
#  (15.848790283007862, 15.89989056709435),
#  (10.579306565398966, 17.609781223114283),
#  (13.671846975415011, 1.5208550734190878),
#  (17.26347656377314, 19.12820530556847),
#  (13.483668680735953, 10.140503560497674),
#  (7.699778017520965, 25.607558692711816),
#  (19.188601830324018, 4.300866472094539),
#  (30.0, 30.0),
#  (16.68563340884532, 15.352447800461531),
#  (27.480524966248975, 28.534027178571236),
#  (20.1521621743256, 4.033375419033782),
#  (12.663619392973233, 14.615710441499617),
#  (15.926410535876512, 24.835250901274467),
#  (15.412051102363716, 21.797829386804217),
#  (10.322024607067974, 12.645600713729316),
#  (13.526100634998643, 14.505120629084884),
#  (21.197900888830898, 25.59619026882616),
#  (12.050851090698824, 18.975660677537544),
#  (19.577971260846336, 15.703781676343752),
#  (12.199100596641287, 26.238972824922744),
#  (15.815899343777645, 26.212884047437296),
#  (15.21894038488238, 9.187362700858095),
#  (12.832852390070297, 28.09606968196023),
#  (24.979892640442426, 25.497592705956162),
#  (13.759061252989962, 15.477606798891479),
